# %%
import pandas as pd 
import seaborn as sns

# %%
customers_dataset = pd.read_csv('dataset/olist_customers_dataset.csv')
geolocation_dataset = pd.read_csv('dataset/olist_geolocation_dataset.csv')
order_items_dataset = pd.read_csv('dataset/olist_order_items_dataset.csv')
order_payments_dataset = pd.read_csv('dataset/olist_order_payments_dataset.csv')
order_reviews_dataset = pd.read_csv('dataset/olist_order_reviews_dataset.csv')
orders_dataset = pd.read_csv('dataset/olist_orders_dataset.csv')
products_dataset = pd.read_csv('dataset/olist_products_dataset.csv')
sellers_dataset = pd.read_csv('dataset/olist_sellers_dataset.csv')
product_category_name_translation = pd.read_csv('dataset/product_category_name_translation.csv')

# %%
customers_dataset
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 5 columns]

# %%
customers_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
geolocation_dataset.sample(5) # maybe not needed for now
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 131444                         5445       -23.551936       -46.696887
# 622869                        36970       -20.361889       -41.958557
# 543452                        30140       -19.938068       -43.930636
# 449344                        22460       -22.965862       -43.221001
# 50948                          3220       -23.605593       -46.522585
#
#        geolocation_city geolocation_state
# 131444        sao paulo                SP
# 622869       manhumirim                MG
# 543452   belo horizonte                MG
# 449344   rio de janeiro                RJ
# 50948         sao paulo                SP

# %%
order_items_dataset.sample(5)
# Out:
#                                order_id  order_item_id  \
# 58246  849bd27b7510577eef2f081308eded4e              1
# 60486  89da573364809995840e3546344a0113              1
# 79177  b41cc5a0872a7fd886b2cb2e300dbe7a              1
# 29044  4211e9c52967c6118ba50e4efde875a5              1
# 42461  60b7a154dfbcedf1c0b7b294d0cfae7b              1
#
#                              product_id                         seller_id  \
# 58246  f2533dc1eb7dca7f684254fbfa98caf8  4a3ca9315b744ce9f8e9374361493884
# 60486  41cd333a4af5e36df81fc0b83ccf8e2d  5dceca129747e92ff8ef7a997dc4f8ca
# 79177  05f0fe07929d35be0748fac56eecbeb2  c70c1b0d8ca86052f45a432a38b73958
# 29044  11fb16e86df4d50cd2c289ede0b70f42  1eade46fba20122dc4aefb379f8c636b
# 42461  c9c6fde711572c1ad99ca12728c6af00  562fc2f2c2863ab7e79a9e4388a58a14
#
#        shipping_limit_date   price  freight_value
# 58246  2017-08-23 20:30:09  135.00          12.45
# 60486  2017-11-23 18:55:31  388.00          15.27
# 79177  2018-07-23 04:31:56  110.32           8.03
# 29044  2018-01-31 11:53:08   14.99           7.78
# 42461  2018-02-12 03:50:48   29.99          25.38

# %%
order_payments_dataset.sample(5)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 52686   432741a23747a84de00c2483f78eec05                   1       boleto
# 36979   92ebca361a35d3b733c6b4bb54dc673a                   1  credit_card
# 101690  67e3d81838ef7ed9d7251f0514c235bb                   1  credit_card
# 13991   d8d2a08b724c4ce7446dea366703745c                   1       boleto
# 33202   e5fc50f8d64012ac844e3ac50b40fae5                   1  credit_card
#
#         payment_installments  payment_value
# 52686                      1         108.20
# 36979                      2          45.22
# 101690                     5         130.04
# 13991                      1         152.94
# 33202                      1          64.03

# %%
order_reviews_dataset.sample(5)
# Out:
#                               review_id                          order_id  \
# 70443  0e7fa08b4fb918001c116540de8f5f70  db43c1a570e28fe9da60a444e3616a2b
# 3969   4fa62a3aeef9a1b3d056ae9cdc776030  ba5c577357e3f0b4d142808039a7ada5
# 14424  0cd0cabb90e7db1d6f8a03377a7c7e00  5c455e9a6d56d30c1652aea99d744e5c
# 61092  23789cacb099079fa3d37208404fa318  821b1d19ba63b3109388a4bbc84d3f43
# 11890  472c74f3989ccce851497dff5efab7f8  cdd88fe2cf9ac965891c9fc6b17c9c9c
#
#        review_score review_comment_title  \
# 70443             5                  NaN
# 3969              5        Otimo Produto
# 14424             2   Comprei 2 produtos
# 61092             5                  NaN
# 11890             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 70443           entregue dentro do prazo super recomendo  2017-10-04 00:00:00
# 3969   Produto excelente, de custo baixo, ou seja jun...  2018-08-24 00:00:00
# 14424  O case para HD, chegou corretamente, mas a cap...  2018-05-20 00:00:00
# 61092                                                NaN  2018-01-31 00:00:00
# 11890                                                NaN  2018-03-22 00:00:00
#
#       review_answer_timestamp
# 70443     2017-10-05 13:05:35
# 3969      2018-08-27 11:46:00
# 14424     2018-05-21 20:04:02
# 61092     2018-02-01 20:08:08
# 11890     2018-06-18 03:31:52

# %%
orders_dataset
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
orders_dataset[orders_dataset['customer_id'] == '06b8999e2fba1a1fbc88172c00ba8bc7']
# Out:
#                                order_id                       customer_id  \
# 88492  00e7ee1b050b8499577073aeb2a297a1  06b8999e2fba1a1fbc88172c00ba8bc7
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 88492    delivered      2017-05-16 15:05:35  2017-05-16 15:22:12
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 88492          2017-05-23 10:47:57           2017-05-25 10:35:35
#
#       order_estimated_delivery_date
# 88492           2017-06-05 00:00:00

# %%
products_dataset.sample(5)
# Out:
#                              product_id  product_category_name  \
# 2714   80d3aeff2ab6c9d795010c029dbd5ddd            moveis_sala
# 1362   69d4040bce5f682537d8e124d1cbc2eb               pet_shop
# 17439  70d7a4737a91965066483a5b0d26a19e  instrumentos_musicais
# 25833  1b5978db99f7114b364fa0a0123eda05     relogios_presentes
# 16335  3c5b70965b3d63c66a18dd46881a58c9  utilidades_domesticas
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 2714                  31.0                       342.0                 1.0
# 1362                  52.0                       458.0                 3.0
# 17439                 46.0                       638.0                 1.0
# 25833                 49.0                       613.0                 3.0
# 16335                 47.0                       456.0                 6.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 2714             4350.0               58.0               15.0
# 1362              150.0               26.0                6.0
# 17439            2423.0               36.0               17.0
# 25833            4100.0               19.0               10.0
# 16335             700.0               19.0               16.0
#
#        product_width_cm
# 2714               53.0
# 1362               19.0
# 17439              22.0
# 25833              15.0
# 16335              16.0

# %%
sellers_dataset.sample(5)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 3013  fcf16b7a8697e559f0123190bb30177d                    3679
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 401   38f276ca6e7cc95a6d1bb55ac9e5550f                   17520
# 2210  d20b021d3efdf267a402c402a48ea64b                   14940
# 2405  62de60d81c55c29d76a6bce418b31cef                   14940
#
#          seller_city seller_state
# 3013       sao paulo           SP
# 2     rio de janeiro           RJ
# 401          marilia           SP
# 2210        ibitinga           SP
# 2405        ibitinga           SP

# %%
product_category_name_translation.sample(5)
# Out:
#                  product_category_name product_category_name_english
# 3                      cama_mesa_banho                bed_bath_table
# 50      fashion_underwear_e_moda_praia       fashion_underwear_beach
# 0                         beleza_saude                 health_beauty
# 36  construcao_ferramentas_ferramentas       costruction_tools_tools
# 14                          brinquedos                          toys

# %% [markdown]
# # insights
# 1. Revenue Trends: Monthly/quarterly sales trends, peak seasons (e.g., Black Friday), YoY growth.
#         orders, order_items, products, product_category_translation
# 2. Churn Analysis: Track one-time vs. repeat buyers and factors influencing retention (e.g., delivery delays, poor reviews).
#     Tables Involved: customers, orders, geolocation, reviews.
#
# 3. Top Categories/Products: Best-selling categories, revenue contribution, and inventory turnover.
#
# 4. Product Pairing: Association analysis (e.g., products frequently bought together).
#
# 5. Seasonality: Category-specific trends (e.g., gifts in December).
#     Tables Involved: order_items, products, product_category_translation.
#
# 6. Delivery Delays: Compare estimated vs. actual delivery times. (may affect the seller)
#
# 7. Sales Hotspots: States/cities contributing most revenue.
#
# 8. Regional Preferences: Product category popularity by region (e.g., warmer states buying more beachwear).

# %% [markdown]
# ## questions to ask
# Which product categories have the highest customer satisfaction (reviews) but low sales?
#
# Do sellers with faster shipping times receive better reviews?
#
# What payment methods dominate high-value orders?
#
# Which states have the longest delays between order approval and delivery?
#
# Which cities have the highest density of sellers but low customer bases?
#
#
# How do delivery delays impact review scores?
#
#
# Which regions have the longest delivery delays, and why?
#
# Are there seasonal spikes in specific product categories (e.g., holidays, festivals)?
#
# Which products are frequently purchased together?
#
# What percentage of customers are repeat buyers vs. one-time purchasers?
#
# Do customers in urban areas (e.g., São Paulo) spend more than those in rural regions?
#
# ***What is the average customer lifetime value (CLV) for different regions?
#
# *** How do seller review scores correlate with their order fulfillment speed?

# %%
# Step 1: Translate product categories using product_category_name_translation
# Rename columns in the translation dataset for clarity
product_category_name_translation.rename(columns={
    'product_category_name': 'product_category_name_portuguese',
    'product_category_name_english': 'product_category_name_english'
}, inplace=True)

# Merge products_dataset with the translation dataset
products_dataset = pd.merge(
    products_dataset,
    product_category_name_translation,
    left_on='product_category_name',
    right_on='product_category_name_portuguese',
    how='left'
)

# Drop the Portuguese category column if you only need the English version
products_dataset.drop(columns=['product_category_name_portuguese'], inplace=True)

# Step 2: Merge orders and order items
sales_data = pd.merge(orders_dataset, order_items_dataset, on='order_id', how='inner')

# Step 3: Add product details (including translated categories)
sales_data = pd.merge(sales_data, products_dataset, on='product_id', how='left')

# Step 4: Add customer details
sales_data = pd.merge(sales_data, customers_dataset, on='customer_id', how='left')

# Step 5: Add seller details
sales_data = pd.merge(sales_data, sellers_dataset, on='seller_id', how='left')

# Step 6: Add payment details
sales_data = pd.merge(sales_data, order_payments_dataset, on='order_id', how='left')

# Step 7: Add review details
sales_data = pd.merge(sales_data, order_reviews_dataset, on='order_id', how='left')

# %%
pd.set_option('display.max_columns', None)

# %%
sales_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118305  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118306  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118307  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118308  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118309  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3         delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4         delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# ...             ...                      ...                  ...
# 118305    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 118306    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 118307    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 118308    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 118309    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2017-10-04 19:55:00           2017-10-10 21:25:13
# 2               2017-10-04 19:55:00           2017-10-10 21:25:13
# 3               2018-07-26 14:31:00           2018-08-07 15:27:45
# 4               2018-08-08 13:50:00           2018-08-17 18:06:29
# ...                             ...                           ...
# 118305          2018-02-07 23:22:42           2018-02-28 17:37:56
# 118306          2017-08-28 20:52:26           2017-09-21 11:24:17
# 118307          2018-01-12 15:35:03           2018-01-25 23:32:54
# 118308          2018-01-12 15:35:03           2018-01-25 23:32:54
# 118309          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#        order_estimated_delivery_date  order_item_id  \
# 0                2017-10-18 00:00:00              1
# 1                2017-10-18 00:00:00              1
# 2                2017-10-18 00:00:00              1
# 3                2018-08-13 00:00:00              1
# 4                2018-09-04 00:00:00              1
# ...                              ...            ...
# 118305           2018-03-02 00:00:00              1
# 118306           2017-09-27 00:00:00              1
# 118307           2018-02-15 00:00:00              1
# 118308           2018-02-15 00:00:00              2
# 118309           2018-04-03 00:00:00              1
#
#                               product_id                         seller_id  \
# 0       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3       595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4       aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# ...                                  ...                               ...
# 118305  f1d4ce8c6dd66c47bbaa8c6781c2a923  1f9ab4708f3056ede07124aad39a2554
# 118306  b80910977a37536adeddd63663f916ad  d50d79cb34e38265a8649c383dcffd48
# 118307  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 118308  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 118309  006619bbed68b000c8ba3f8725d5409e  ececbfcff9804a2d6b40f589df8eef2b
#
#         shipping_limit_date   price  freight_value   product_category_name  \
# 0       2017-10-06 11:07:15   29.99           8.72   utilidades_domesticas
# 1       2017-10-06 11:07:15   29.99           8.72   utilidades_domesticas
# 2       2017-10-06 11:07:15   29.99           8.72   utilidades_domesticas
# 3       2018-07-30 03:24:27  118.70          22.76              perfumaria
# 4       2018-08-13 08:55:23  159.90          19.22              automotivo
# ...                     ...     ...            ...                     ...
# 118305  2018-02-12 13:10:37  174.90          20.10                   bebes
# 118306  2017-09-05 15:04:16  205.99          65.02      eletrodomesticos_2
# 118307  2018-01-12 21:36:21  179.99          40.59  informatica_acessorios
# 118308  2018-01-12 21:36:21  179.99          40.59  informatica_acessorios
# 118309  2018-03-15 10:55:42   68.50          18.36            beleza_saude
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       268.0                 4.0
# 1                      40.0                       268.0                 4.0
# 2                      40.0                       268.0                 4.0
# 3                      29.0                       178.0                 1.0
# 4                      46.0                       232.0                 1.0
# ...                     ...                         ...                 ...
# 118305                 52.0                       828.0                 4.0
# 118306                 51.0                       500.0                 2.0
# 118307                 59.0                      1893.0                 1.0
# 118308                 59.0                      1893.0                 1.0
# 118309                 45.0                       569.0                 1.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 0                  500.0               19.0                8.0
# 1                  500.0               19.0                8.0
# 2                  500.0               19.0                8.0
# 3                  400.0               19.0               13.0
# 4                  420.0               24.0               19.0
# ...                  ...                ...                ...
# 118305            4950.0               40.0               10.0
# 118306           13300.0               32.0               90.0
# 118307            6550.0               20.0               20.0
# 118308            6550.0               20.0               20.0
# 118309             150.0               16.0                7.0
#
#         product_width_cm product_category_name_english  \
# 0                   13.0                    housewares
# 1                   13.0                    housewares
# 2                   13.0                    housewares
# 3                   19.0                     perfumery
# 4                   21.0                          auto
# ...                  ...                           ...
# 118305              40.0                          baby
# 118306              22.0             home_appliances_2
# 118307              20.0         computers_accessories
# 118308              20.0         computers_accessories
# 118309              15.0                 health_beauty
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       7c396fd4830fd04220f754e42b4e5bff                      3149
# 1       7c396fd4830fd04220f754e42b4e5bff                      3149
# 2       7c396fd4830fd04220f754e42b4e5bff                      3149
# 3       af07308b275d755c9edb36a90c618231                     47813
# 4       3a653a41f6f9fc3d2a113cf8398680e8                     75265
# ...                                  ...                       ...
# 118305  da62f9e57a76d978d02ab5362c509660                     11722
# 118306  737520a9aad80b3fbbdad19b66b37b30                     45920
# 118307  5097a5312c8b157bb7be58ae360ef43c                     28685
# 118308  5097a5312c8b157bb7be58ae360ef43c                     28685
# 118309  60350aa974b26ff12caad89e55993bd6                     83750
#
#        customer_city customer_state  seller_zip_code_prefix     seller_city  \
# 0          sao paulo             SP                    9350            maua
# 1          sao paulo             SP                    9350            maua
# 2          sao paulo             SP                    9350            maua
# 3          barreiras             BA                   31570  belo horizonte
# 4         vianopolis             GO                   14840         guariba
# ...              ...            ...                     ...             ...
# 118305  praia grande             SP                   17602            tupa
# 118306   nova vicosa             BA                    8290       sao paulo
# 118307       japuiba             RJ                   37175        ilicinea
# 118308       japuiba             RJ                   37175        ilicinea
# 118309          lapa             PR                   14407          franca
#
#        seller_state  payment_sequential payment_type  payment_installments  \
# 0                SP                 1.0  credit_card                   1.0
# 1                SP                 3.0      voucher                   1.0
# 2                SP                 2.0      voucher                   1.0
# 3                SP                 1.0       boleto                   1.0
# 4                SP                 1.0  credit_card                   3.0
# ...             ...                 ...          ...                   ...
# 118305           SP                 1.0  credit_card                   3.0
# 118306           SP                 1.0  credit_card                   5.0
# 118307           MG                 1.0  credit_card                   4.0
# 118308           MG                 1.0  credit_card                   4.0
# 118309           SP                 1.0   debit_card                   1.0
#
#         payment_value                         review_id  review_score  \
# 0               18.12  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 1                2.00  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 2               18.59  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 3              141.46  8d5266042046a06655c8db133d120ba5           4.0
# 4              179.12  e73b67b67587f7644d5bd1a52deb1b01           5.0
# ...               ...                               ...           ...
# 118305         195.00  29bb71b2760d0f876dfa178a76bc4734           4.0
# 118306         271.01  371579771219f6db2d830d50805977bb           5.0
# 118307         441.16  8ab6855b9fe9b812cd03a480a25058a1           2.0
# 118308         441.16  8ab6855b9fe9b812cd03a480a25058a1           2.0
# 118309          86.86  dc9c59b4688062c25758c2be4cafc523           5.0
#
#        review_comment_title  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3          Muito boa a loja
# 4                       NaN
# ...                     ...
# 118305                  NaN
# 118306                  NaN
# 118307                  NaN
# 118308                  NaN
# 118309                  NaN
#
#                                    review_comment_message  \
# 0       Não testei o produto ainda, mas ele veio corre...
# 1       Não testei o produto ainda, mas ele veio corre...
# 2       Não testei o produto ainda, mas ele veio corre...
# 3                                    Muito bom o produto.
# 4                                                     NaN
# ...                                                   ...
# 118305       So uma peça que veio rachado mas tudo bem rs
# 118306                       Foi entregue antes do prazo.
# 118307  Foi entregue somente 1. Quero saber do outro p...
# 118308  Foi entregue somente 1. Quero saber do outro p...
# 118309                                                NaN
#
#        review_creation_date review_answer_timestamp
# 0       2017-10-11 00:00:00     2017-10-12 03:43:48
# 1       2017-10-11 00:00:00     2017-10-12 03:43:48
# 2       2017-10-11 00:00:00     2017-10-12 03:43:48
# 3       2018-08-08 00:00:00     2018-08-08 18:37:50
# 4       2018-08-18 00:00:00     2018-08-22 19:07:58
# ...                     ...                     ...
# 118305  2018-03-01 00:00:00     2018-03-02 17:50:01
# 118306  2017-09-22 00:00:00     2017-09-22 23:10:57
# 118307  2018-01-26 00:00:00     2018-01-27 09:16:56
# 118308  2018-01-26 00:00:00     2018-01-27 09:16:56
# 118309  2018-03-17 00:00:00     2018-03-17 16:33:31
#
# [118310 rows x 40 columns]

# %%
sales_data.sample(5)
# Out:
#                                 order_id                       customer_id  \
# 107928  ddb18ea9ad3aa3a2ab5420b75a12458b  31bd0dc8763b2f3fc256b8fece76ecab
# 32363   4aea73f4a5803237a93ce646f0f91b16  7bdd1a8a8a27b40561a9ad6fc2889383
# 60582   566d1e57b2fc70ca4a32dadbd0bbd0a1  4b2ee5585c081b18bcaa8a2682564d19
# 45698   62f1923bf7409f0a4c029c4576499d4f  5d574e44c76dd451c45b92c78cb27863
# 72682   37eba161f3994d1eec4b755ba3565003  93cd96511720c79840c463a530e84fe9
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 107928    delivered      2017-04-30 14:37:45  2017-04-30 14:45:19
# 32363     delivered      2017-05-16 18:49:31  2017-05-16 19:02:16
# 60582     delivered      2017-10-07 15:33:38  2017-10-08 15:42:17
# 45698     delivered      2018-03-23 16:39:40  2018-03-23 16:50:59
# 72682     delivered      2018-02-06 13:07:55  2018-02-06 13:15:38
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 107928          2017-05-02 14:08:56           2017-05-16 10:53:54
# 32363           2017-05-18 10:43:25           2017-05-22 13:57:53
# 60582           2017-10-09 16:02:21           2017-10-17 22:32:36
# 45698           2018-03-26 22:09:00           2018-03-27 15:37:00
# 72682           2018-02-07 22:27:00           2018-02-22 22:35:43
#
#        order_estimated_delivery_date  order_item_id  \
# 107928           2017-06-01 00:00:00              1
# 32363            2017-06-16 00:00:00              2
# 60582            2017-11-06 00:00:00              1
# 45698            2018-04-05 00:00:00              1
# 72682            2018-03-06 00:00:00              1
#
#                               product_id                         seller_id  \
# 107928  c71bf92cf123eb294304073fc1751bf3  c3cfdc648177fdbbbb35635a37472c53
# 32363   154e7e31ebfa092203795c972e5804a6  cc419e0650a3c5ba77189a1882b7556a
# 60582   31c1d1dfbb4b2730140b8bd9248bcd58  da8622b14eb17ae2831f4ac5b9dab84a
# 45698   7ce94ab189134e2d3c05f496d635419c  8b321bb669392f5163d04c59e235e066
# 72682   ff7fccf8513f360157f0660fe51d1d88  440dd6ab244315c632130ecfb63827b1
#
#         shipping_limit_date   price  freight_value product_category_name  \
# 107928  2017-05-10 14:45:19  300.00          25.92         esporte_lazer
# 32363   2017-05-25 19:02:16   19.99           8.91          beleza_saude
# 60582   2017-10-13 15:42:17   24.90          15.10       cama_mesa_banho
# 45698   2018-03-29 16:50:59   13.65           7.39           eletronicos
# 72682   2018-02-12 13:15:38  170.00          18.44         esporte_lazer
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 107928                 59.0                      1714.0                 1.0
# 32363                  48.0                       575.0                 1.0
# 60582                  58.0                        58.0                 1.0
# 45698                  39.0                       400.0                 1.0
# 72682                  59.0                      1313.0                 2.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 107928            3000.0               36.0               31.0
# 32363              100.0               20.0               15.0
# 60582              200.0               20.0                2.0
# 45698              200.0               25.0                7.0
# 72682             1500.0               80.0               14.0
#
#         product_width_cm product_category_name_english  \
# 107928              31.0                sports_leisure
# 32363               15.0                 health_beauty
# 60582               15.0                bed_bath_table
# 45698               16.0                   electronics
# 72682               16.0                sports_leisure
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 107928  3bab949ef05da8e9b3cfd541b6af0ffd                     38020
# 32363   46f15c2526277c2f9cfa6b239dfb11b3                     36730
# 60582   6620337ac07f171920b001d6714d82ac                     38742
# 45698   34b299f441d2c39d21047961ffb9932b                      7020
# 72682   c2ddee887c6027dd5d19603be6cfc6c6                     32600
#
#        customer_city customer_state  seller_zip_code_prefix  seller_city  \
# 107928       uberaba             MG                   80610     curitiba
# 32363    pirapetinga             MG                    9015  santo andre
# 60582     patrocinio             MG                   13405   piracicaba
# 45698      guarulhos             SP                    1212    sao paulo
# 72682          betim             MG                   15502  votuporanga
#
#        seller_state  payment_sequential payment_type  payment_installments  \
# 107928           PR                 1.0  credit_card                   1.0
# 32363            SP                 1.0  credit_card                   3.0
# 60582            SP                 1.0  credit_card                   2.0
# 45698            SP                 1.0  credit_card                   1.0
# 72682            SP                 1.0  credit_card                  10.0
#
#         payment_value                         review_id  review_score  \
# 107928         325.92  22744b0996a87030c4cb8cd9362674cb           5.0
# 32363          115.28  33bdedfcc676d7e2ddcca1c5f0237012           5.0
# 60582           40.00  e6540e85fd496aaa5f1254e3231c42fc           5.0
# 45698           21.04  cf93a76fe49b525bc175d89624813f8e           5.0
# 72682          188.44  040ba96e27624e10241a360314192fac           5.0
#
#        review_comment_title  \
# 107928                  NaN
# 32363                   NaN
# 60582                   NaN
# 45698                   NaN
# 72682                   NaN
#
#                                    review_comment_message  \
# 107928                                                NaN
# 32363                                                 NaN
# 60582                                                 NaN
# 45698   Produto como descrito, chegou antes do prazo f...
# 72682                                                 NaN
#
#        review_creation_date review_answer_timestamp
# 107928  2017-05-17 00:00:00     2017-05-20 13:43:40
# 32363   2017-05-23 00:00:00     2017-05-26 09:00:24
# 60582   2017-10-18 00:00:00     2017-10-21 01:14:26
# 45698   2018-03-28 00:00:00     2018-03-29 22:22:27
# 72682   2018-02-23 00:00:00     2018-02-24 02:13:07

# %%
sales_data[sales_data['customer_id']=='06b8999e2fba1a1fbc88172c00ba8bc7']
# Out:
#                                 order_id                       customer_id  \
# 105115  00e7ee1b050b8499577073aeb2a297a1  06b8999e2fba1a1fbc88172c00ba8bc7
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 105115    delivered      2017-05-16 15:05:35  2017-05-16 15:22:12
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 105115          2017-05-23 10:47:57           2017-05-25 10:35:35
#
#        order_estimated_delivery_date  order_item_id  \
# 105115           2017-06-05 00:00:00              1
#
#                               product_id                         seller_id  \
# 105115  a9516a079e37a9c9c36b9b78b10169e8  7c67e1448b00f6e969d365cea6b010ab
#
#         shipping_limit_date   price  freight_value product_category_name  \
# 105115  2017-05-22 15:22:12  124.99          21.88     moveis_escritorio
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 105115                 41.0                      1141.0                 1.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 105115            8683.0               54.0               64.0
#
#         product_width_cm product_category_name_english  \
# 105115              31.0              office_furniture
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 105115  861eff4711a542e4b93843c6dd7febb0                     14409
#
#        customer_city customer_state  seller_zip_code_prefix      seller_city  \
# 105115        franca             SP                    8577  itaquaquecetuba
#
#        seller_state  payment_sequential payment_type  payment_installments  \
# 105115           SP                 1.0  credit_card                   2.0
#
#         payment_value                         review_id  review_score  \
# 105115         146.87  88b8b52d46df026a9d1ad2136a59b30b           4.0
#
#        review_comment_title review_comment_message review_creation_date  \
# 105115                  NaN                    NaN  2017-05-26 00:00:00
#
#        review_answer_timestamp
# 105115     2017-05-30 22:34:40

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118310 entries, 0 to 118309
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118310 non-null  object
#  1   customer_id                    118310 non-null  object
#  2   order_status                   118310 non-null  object
#  3   order_purchase_timestamp       118310 non-null  object
#  4   order_approved_at              118295 non-null  object
#  5   order_delivered_carrier_date   117056 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  118310 non-null  object
#  8   order_item_id                  118310 non-null  int64
#  9   product_id                     118310 non-null  object
#  10  seller_id                      118310 non-null  object
#  11  shipping_limit_date            118310 non-null  object
#  12  price                          118310 non-null  float64
#  13  freight_value                  118310 non-null  float64
#  14  product_category_name          116601 non-null  object
#  15  product_name_lenght            116601 non-null  float64
#  16  product_description_lenght     116601 non-null  float64
#  17  product_photos_qty             116601 non-null  float64
#  18  product_weight_g               118290 non-null  float64
#  19  product_length_cm              118290 non-null  float64
#  20  product_height_cm              118290 non-null  float64
#  21  product_width_cm               118290 non-null  float64
#  22  product_category_name_english  116576 non-null  object
#  23  customer_unique_id             118310 non-null  object
#  24  customer_zip_code_prefix       118310 non-null  int64
#  25  customer_city                  118310 non-null  object
#  26  customer_state                 118310 non-null  object
#  27  seller_zip_code_prefix         118310 non-null  int64
#  28  seller_city                    118310 non-null  object
#  29  seller_state                   118310 non-null  object
#  30  payment_sequential             118307 non-null  float64
#  31  payment_type                   118307 non-null  object
#  32  payment_installments           118307 non-null  float64
#  33  payment_value                  118307 non-null  float64
#  34  review_id                      117332 non-null  object
#  35  review_score                   117332 non-null  float64
#  36  review_comment_title           13892 non-null   object
#  37  review_comment_message         49682 non-null   object
#  38  review_creation_date           117332 non-null  object
#  39  review_answer_timestamp        117332 non-null  object
# dtypes: float64(13), int64(3), object(24)
# memory usage: 36.1+ MB

# %%
# to know the number of missing values in each column
for column in sales_data.columns:
    null_count = sales_data[column].isnull().sum()
    print(f"Column: {column}, Null Count: {null_count}")
# Out:
# Column: order_id, Null Count: 0
# Column: customer_id, Null Count: 0
# Column: order_status, Null Count: 0
# Column: order_purchase_timestamp, Null Count: 0
# Column: order_approved_at, Null Count: 15
# Column: order_delivered_carrier_date, Null Count: 1254
# Column: order_delivered_customer_date, Null Count: 2588
# Column: order_estimated_delivery_date, Null Count: 0
# Column: order_item_id, Null Count: 0
# Column: product_id, Null Count: 0
# Column: seller_id, Null Count: 0
# Column: shipping_limit_date, Null Count: 0
# Column: price, Null Count: 0
# Column: freight_value, Null Count: 0
# Column: product_category_name, Null Count: 1709
# Column: product_name_lenght, Null Count: 1709
# Column: product_description_lenght, Null Count: 1709
# Column: product_photos_qty, Null Count: 1709
# Column: product_weight_g, Null Count: 20
# Column: product_length_cm, Null Count: 20
# Column: product_height_cm, Null Count: 20
# Column: product_width_cm, Null Count: 20
# Column: product_category_name_english, Null Count: 1734
# Column: customer_unique_id, Null Count: 0
# Column: customer_zip_code_prefix, Null Count: 0
# Column: customer_city, Null Count: 0
# Column: customer_state, Null Count: 0
# Column: seller_zip_code_prefix, Null Count: 0
# Column: seller_city, Null Count: 0
# Column: seller_state, Null Count: 0
# Column: payment_sequential, Null Count: 3
# Column: payment_type, Null Count: 3
# Column: payment_installments, Null Count: 3
# Column: payment_value, Null Count: 3
# Column: review_id, Null Count: 978
# Column: review_score, Null Count: 978
# Column: review_comment_title, Null Count: 104418
# Column: review_comment_message, Null Count: 68628
# Column: review_creation_date, Null Count: 978
# Column: review_answer_timestamp, Null Count: 978

# %%
# Calculate percentage of missing values for each column
missing_percent = (sales_data.isnull().sum() / len(sales_data)) * 100

# Filter columns with missing values and format as percentages
missing_percent_formatted = missing_percent[missing_percent > 0].apply(lambda x: f"{x:.2f}%")

# Print the result
print(missing_percent_formatted)
# Out:
# order_approved_at                 0.01%
# order_delivered_carrier_date      1.06%
# order_delivered_customer_date     2.19%
# product_category_name             1.44%
# product_name_lenght               1.44%
# product_description_lenght        1.44%
# product_photos_qty                1.44%
# product_weight_g                  0.02%
# product_length_cm                 0.02%
# product_height_cm                 0.02%
# product_width_cm                  0.02%
# product_category_name_english     1.47%
# payment_sequential                0.00%
# payment_type                      0.00%
# payment_installments              0.00%
# payment_value                     0.00%
# review_id                         0.83%
# review_score                      0.83%
# review_comment_title             88.26%
# review_comment_message           58.01%
# review_creation_date              0.83%
# review_answer_timestamp           0.83%
# dtype: object

# %%
# here to see what is in the review_comment_title column
sales_data['review_comment_title'].head(30)
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3     Muito boa a loja
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19            Nota dez
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# Name: review_comment_title, dtype: object

# %%
sales_data['review_comment_message'].head(30)
# Out:
# 0     Não testei o produto ainda, mas ele veio corre...
# 1     Não testei o produto ainda, mas ele veio corre...
# 2     Não testei o produto ainda, mas ele veio corre...
# 3                                  Muito bom o produto.
# 4                                                   NaN
# 5     O produto foi exatamente o que eu esperava e e...
# 6                                                   NaN
# 7                                                   NaN
# 8                  fiquei triste por n ter me atendido.
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                           Aguardando retorno da loja
# 14                           Aguardando retorno da loja
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                    Gostei do produto
# 19    Obrigado pela atenção. Lojas lannister perfeit...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26    os correios estäo em greve... näo recebi nenhu...
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# Name: review_comment_message, dtype: object

# %%
# decided to drop the review_comment_title column as it doesn't show any useful information

# %% [markdown]
# # Drop rows with any missing values
# sales_data_cleaned = sales_data.dropna()
#
# # Or drop rows with missing values in specific columns
# sales_data_cleaned = sales_data.dropna(subset=['price', 'freight_value'])

# %%
#sales_data.drop(columns=['review_comment_message', 'review_comment_title'], inplace=True)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118310 entries, 0 to 118309
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118310 non-null  object
#  1   customer_id                    118310 non-null  object
#  2   order_status                   118310 non-null  object
#  3   order_purchase_timestamp       118310 non-null  object
#  4   order_approved_at              118295 non-null  object
#  5   order_delivered_carrier_date   117056 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  118310 non-null  object
#  8   order_item_id                  118310 non-null  int64
#  9   product_id                     118310 non-null  object
#  10  seller_id                      118310 non-null  object
#  11  shipping_limit_date            118310 non-null  object
#  12  price                          118310 non-null  float64
#  13  freight_value                  118310 non-null  float64
#  14  product_category_name          116601 non-null  object
#  15  product_name_lenght            116601 non-null  float64
#  16  product_description_lenght     116601 non-null  float64
#  17  product_photos_qty             116601 non-null  float64
#  18  product_weight_g               118290 non-null  float64
#  19  product_length_cm              118290 non-null  float64
#  20  product_height_cm              118290 non-null  float64
#  21  product_width_cm               118290 non-null  float64
#  22  product_category_name_english  116576 non-null  object
#  23  customer_unique_id             118310 non-null  object
#  24  customer_zip_code_prefix       118310 non-null  int64
#  25  customer_city                  118310 non-null  object
#  26  customer_state                 118310 non-null  object
#  27  seller_zip_code_prefix         118310 non-null  int64
#  28  seller_city                    118310 non-null  object
#  29  seller_state                   118310 non-null  object
#  30  payment_sequential             118307 non-null  float64
#  31  payment_type                   118307 non-null  object
#  32  payment_installments           118307 non-null  float64
#  33  payment_value                  118307 non-null  float64
#  34  review_id                      117332 non-null  object
#  35  review_score                   117332 non-null  float64
#  36  review_comment_title           13892 non-null   object
#  37  review_comment_message         49682 non-null   object
#  38  review_creation_date           117332 non-null  object
#  39  review_answer_timestamp        117332 non-null  object
# dtypes: float64(13), int64(3), object(24)
# memory usage: 36.1+ MB

# %%
# here i will drop the rows with missing values in the dataframe

# %%
sales_data_cleaned = sales_data.dropna()

# %%
sales_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11578 entries, 3 to 118291
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       11578 non-null  object
#  1   customer_id                    11578 non-null  object
#  2   order_status                   11578 non-null  object
#  3   order_purchase_timestamp       11578 non-null  object
#  4   order_approved_at              11578 non-null  object
#  5   order_delivered_carrier_date   11578 non-null  object
#  6   order_delivered_customer_date  11578 non-null  object
#  7   order_estimated_delivery_date  11578 non-null  object
#  8   order_item_id                  11578 non-null  int64
#  9   product_id                     11578 non-null  object
#  10  seller_id                      11578 non-null  object
#  11  shipping_limit_date            11578 non-null  object
#  12  price                          11578 non-null  float64
#  13  freight_value                  11578 non-null  float64
#  14  product_category_name          11578 non-null  object
#  15  product_name_lenght            11578 non-null  float64
#  16  product_description_lenght     11578 non-null  float64
#  17  product_photos_qty             11578 non-null  float64
#  18  product_weight_g               11578 non-null  float64
#  19  product_length_cm              11578 non-null  float64
#  20  product_height_cm              11578 non-null  float64
#  21  product_width_cm               11578 non-null  float64
#  22  product_category_name_english  11578 non-null  object
#  23  customer_unique_id             11578 non-null  object
#  24  customer_zip_code_prefix       11578 non-null  int64
#  25  customer_city                  11578 non-null  object
#  26  customer_state                 11578 non-null  object
#  27  seller_zip_code_prefix         11578 non-null  int64
#  28  seller_city                    11578 non-null  object
#  29  seller_state                   11578 non-null  object
#  30  payment_sequential             11578 non-null  float64
#  31  payment_type                   11578 non-null  object
#  32  payment_installments           11578 non-null  float64
#  33  payment_value                  11578 non-null  float64
#  34  review_id                      11578 non-null  object
#  35  review_score                   11578 non-null  float64
#  36  review_comment_title           11578 non-null  object
#  37  review_comment_message         11578 non-null  object
#  38  review_creation_date           11578 non-null  object
#  39  review_answer_timestamp        11578 non-null  object
# dtypes: float64(13), int64(3), object(24)
# memory usage: 3.6+ MB

# %%
def calculate_missing_value_percentages(df):
    """
    Calculate and display the percentage of missing values for each column in the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame to analyze.

    Returns:
        pd.Series: A Series containing the missing value percentages for columns with missing values.
    """
    # Calculate percentage of missing values for each column
    missing_percent = (df.isnull().sum() / len(df)) * 100
    
    # Filter columns with missing values and format as percentages
    missing_percent_formatted = missing_percent[missing_percent > 0].apply(lambda x: f"{x:.2f}%")
    
    # Print the result
    if not missing_percent_formatted.empty:
        print("Columns with Missing Values (%):")
        print(missing_percent_formatted)
    else:
        print("No missing values found in the DataFrame.")
    
    # Return the formatted Series for further use if

# %%
calculate_missing_value_percentages(sales_data_cleaned)
# Out:
# No missing values found in the DataFrame.

# %%
calculate_missing_value_percentages(sales_data)
# Out:
# Columns with Missing Values (%):
# order_approved_at                 0.01%
# order_delivered_carrier_date      1.06%
# order_delivered_customer_date     2.19%
# product_category_name             1.44%
# product_name_lenght               1.44%
# product_description_lenght        1.44%
# product_photos_qty                1.44%
# product_weight_g                  0.02%
# product_length_cm                 0.02%
# product_height_cm                 0.02%
# product_width_cm                  0.02%
# product_category_name_english     1.47%
# payment_sequential                0.00%
# payment_type                      0.00%
# payment_installments              0.00%
# payment_value                     0.00%
# review_id                         0.83%
# review_score                      0.83%
# review_comment_title             88.26%
# review_comment_message           58.01%
# review_creation_date              0.83%
# review_answer_timestamp           0.83%
# dtype: object

# %%
print(sales_data_cleaned.shape)
# Out:
# (11578, 40)

# %% [markdown]
# # here converting date columns that are objects to datetime type

# %%
date_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'shipping_limit_date','review_creation_date', 'review_answer_timestamp']

for column in sales_data_cleaned.columns:
    if column in date_columns:
        sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])

sales_data_cleaned.dtypes
# Out:
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3362261538.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[column] = pd.to_datetime(sales_data_cleaned[column])
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# order_item_id                             int64
# product_id                               object
# seller_id                                object
# shipping_limit_date              datetime64[ns]
# price                                   float64
# freight_value                           float64
# product_category_name                    object
# product_name_lenght                     float64
# product_description_lenght              float64
# product_photos_qty                      float64
# product_weight_g                        float64
# product_length_cm                       float64
# product_height_cm                       float64
# product_width_cm                        float64
# product_category_name_english            object
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# seller_zip_code_prefix                    int64
# seller_city                              object
# seller_state                             object
# payment_sequential                      float64
# payment_type                             object
# payment_installments                    float64
# payment_value                           float64
# review_id                                object
# review_score                            float64
# review_comment_title                     object
# review_comment_message                   object
# review_creation_date             datetime64[ns]
# review_answer_timestamp          datetime64[ns]
# dtype: object

# %%
sales_data_cleaned['order_delivered_carrier_date']
# Out:
# 3        2018-07-26 14:31:00
# 19       2018-06-11 14:54:00
# 30       2018-08-10 12:29:00
# 32       2018-06-05 13:24:00
# 33       2018-06-05 13:24:00
#                  ...
# 118221   2018-05-18 14:23:00
# 118231   2018-08-29 13:38:00
# 118239   2018-04-23 17:18:40
# 118258   2018-08-15 14:37:00
# 118291   2018-05-16 08:14:00
# Name: order_delivered_carrier_date, Length: 11578, dtype: datetime64[ns]

# %%
print(f"Duplicate orders: {sales_data_cleaned.duplicated(subset=['order_id']).sum()}")
# Out:
# Duplicate orders: 2142

# %%
# Check duplicates based on order_id + product_id + seller_id (common columns for uniqueness)
cols_to_check = ['order_id', 'product_id', 'seller_id', 'price', 'order_item_id']
duplicate_count = sales_data_cleaned.duplicated(subset=cols_to_check).sum()
print(f"Duplicate rows (based on order_id + product_id + seller_id + price): {duplicate_count}")
# Out:
# Duplicate rows (based on order_id + product_id + seller_id + price): 415

# %%
import matplotlib.pyplot as plt

# Function to identify outliers using IQR method
def find_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]

# Identify outliers for all numerical columns
outliers_dict = {}
for column in sales_data_cleaned.select_dtypes(include=['float64', 'int64']).columns:
    outliers_dict[column] = find_outliers(sales_data_cleaned, column)

# Visualize outliers for each column using box plots
for column in sales_data_cleaned.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=sales_data_cleaned[column])
    plt.title(f'Box plot for {column}')
    plt.show()

# %%
sales_data_cleaned.head(10)
# Out:
#                             order_id                       customer_id  \
# 3   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 19  dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 30  f3e7c359154d965827355f39d6b1fdac  62b423aab58096ca514ba6aa06be2f98
# 32  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 33  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 38  1790eea0b567cf50911c057cf20f90f9  52142aa69d8d0e1247ab0cada0f76023
# 45  434d158e96bdd6972ad6e6d73ddcfd22  2a1dfb647f32f4390e7b857c67458536
# 55  5820a1100976432c7968a52da59e9364  2b56e94c2f66f2d97cfa63356f69cee8
# 59  9faeb9b2746b9d7526aef5acb08e2aa0  79183cd650e2bb0d475b0067d45946ac
# 60  9faeb9b2746b9d7526aef5acb08e2aa0  79183cd650e2bb0d475b0067d45946ac
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 3     delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 19    delivered      2018-06-07 19:03:12 2018-06-12 23:31:02
# 30    delivered      2018-08-09 11:44:40 2018-08-10 03:24:51
# 32    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
# 33    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
# 38    delivered      2018-04-16 21:15:39 2018-04-16 22:10:26
# 45    delivered      2018-06-01 12:23:13 2018-06-05 03:35:15
# 55    delivered      2018-07-29 11:24:17 2018-07-29 11:44:19
# 59    delivered      2018-07-26 14:39:59 2018-07-26 14:55:10
# 60    delivered      2018-07-26 14:39:59 2018-07-26 14:55:10
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 3           2018-07-26 14:31:00           2018-08-07 15:27:45
# 19          2018-06-11 14:54:00           2018-06-21 15:34:32
# 30          2018-08-10 12:29:00           2018-08-13 18:24:27
# 32          2018-06-05 13:24:00           2018-06-16 15:20:55
# 33          2018-06-05 13:24:00           2018-06-16 15:20:55
# 38          2018-04-18 13:05:09           2018-05-05 12:28:34
# 45          2018-06-08 11:49:00           2018-06-18 21:32:52
# 55          2018-07-30 13:47:00           2018-08-02 22:09:11
# 59          2018-07-27 12:04:00           2018-07-31 22:26:55
# 60          2018-07-27 12:04:00           2018-07-31 22:26:55
#
#    order_estimated_delivery_date  order_item_id  \
# 3                     2018-08-13              1
# 19                    2018-07-04              1
# 30                    2018-08-17              1
# 32                    2018-07-18              1
# 33                    2018-07-18              2
# 38                    2018-05-15              1
# 45                    2018-07-17              1
# 55                    2018-08-13              1
# 59                    2018-08-16              1
# 60                    2018-08-16              2
#
#                           product_id                         seller_id  \
# 3   595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 19  009c09f439988bc06a93d6b8186dce73  89a51f50b8095ea78d5768f34c13a76f
# 30  e99d69efe684efaa643f99805f7c81bc  55c26bcb609f480eb7868594245febb5
# 32  d70f38e7f79c630f8ea00c993897042c  977f9f63dd360c2a32ece2f93ad6d306
# 33  9451e630d725c4bb7a5a206b48b99486  d673a59aac7a70d8b01e6902bf090a11
# 38  2d8f2be4f08788ee3bf5356af2b2ee6c  d91fb3b7d041e83b64a00a3edfb37e4f
# 45  c7df652246ed7b3300aaf46960c141e4  a5cba26a62b8b4d0145b68b841e62e7f
# 55  1deda1acffb44ed38494667d7e49a9f3  f52c2422904463fdd7741f99045fecb6
# 59  f48eb5c2fde13ca63664f0bb05f55346  f7ba60f8c3f99e7ee4042fdef03b70c4
# 60  f48eb5c2fde13ca63664f0bb05f55346  f7ba60f8c3f99e7ee4042fdef03b70c4
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 3  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 19 2018-06-18 18:59:02  132.4          14.05            perfumaria
# 30 2018-08-14 03:24:51   89.9          14.21             papelaria
# 32 2018-06-13 00:35:10   90.9          48.64                 bebes
# 33 2018-06-13 00:35:10   39.5          48.64                 bebes
# 38 2018-04-22 22:10:26  186.9          38.00          climatizacao
# 45 2018-06-13 03:35:15  445.0          63.17          beleza_saude
# 55 2018-07-31 11:44:19   33.9          18.34         esporte_lazer
# 59 2018-07-30 14:55:10   60.0          15.52         esporte_lazer
# 60 2018-07-30 14:55:10   60.0          15.52         esporte_lazer
#
#     product_name_lenght  product_description_lenght  product_photos_qty  \
# 3                  29.0                       178.0                 1.0
# 19                 39.0                       991.0                 3.0
# 30                 56.0                       115.0                 1.0
# 32                 53.0                       233.0                 1.0
# 33                 52.0                       300.0                 1.0
# 38                 52.0                       331.0                 4.0
# 45                 28.0                      1455.0                 1.0
# 55                 53.0                       891.0                 2.0
# 59                 60.0                      1153.0                 2.0
# 60                 60.0                      1153.0                 2.0
#
#     product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 3              400.0               19.0               13.0              19.0
# 19             150.0               20.0               20.0              20.0
# 30             600.0               33.0               13.0              25.0
# 32           10950.0               41.0               40.0              40.0
# 33             350.0               31.0               10.0              12.0
# 38             100.0               27.0               13.0              17.0
# 45             683.0               29.0               15.0              22.0
# 55            1150.0               27.0               12.0              17.0
# 59             100.0               20.0               11.0              11.0
# 60             100.0               20.0               11.0              11.0
#
#    product_category_name_english                customer_unique_id  \
# 3                      perfumery  af07308b275d755c9edb36a90c618231
# 19                     perfumery  ccafc1c3f270410521c3c6f3b249870f
# 30                    stationery  9c9242ad7f1b52d926ea76778e1c0c57
# 32                          baby  576ea0cab426cd8a00fad9a9c90a4494
# 33                          baby  576ea0cab426cd8a00fad9a9c90a4494
# 38              air_conditioning  a6fefcd9f434474cf6fcd8ed1102fd63
# 45                 health_beauty  5f7d7732b351ce851a158528581af05f
# 55                sports_leisure  cc1a30280651daf2d918ed7868575771
# 59                sports_leisure  c77154776ead8e798c2d684205938f71
# 60                sports_leisure  c77154776ead8e798c2d684205938f71
#
#     customer_zip_code_prefix            customer_city customer_state  \
# 3                      47813                barreiras             BA
# 19                     74820                  goiania             GO
# 30                     18052                 sorocaba             SP
# 32                     41213                 salvador             BA
# 33                     41213                 salvador             BA
# 38                     55540                 palmares             PE
# 45                     54330  jaboatao dos guararapes             PE
# 55                     95270          flores da cunha             RS
# 59                     90620             porto alegre             RS
# 60                     90620             porto alegre             RS
#
#     seller_zip_code_prefix            seller_city seller_state  \
# 3                    31570         belo horizonte           SP
# 19                   71931               brasilia           DF
# 30                   14910              tabatinga           SP
# 32                   14910              tabatinga           SP
# 33                   14940               ibitinga           SP
# 38                   11704           praia grande           SP
# 45                   87303           campo mourao           PR
# 55                    9230  santo andre/sao paulo           SP
# 59                    9628  sao bernardo do campo           SP
# 60                    9628  sao bernardo do campo           SP
#
#     payment_sequential payment_type  payment_installments  payment_value  \
# 3                  1.0       boleto                   1.0         141.46
# 19                 1.0  credit_card                  10.0         146.45
# 30                 1.0       boleto                   1.0         104.11
# 32                 1.0  credit_card                  10.0         227.68
# 33                 1.0  credit_card                  10.0         227.68
# 38                 1.0  credit_card                   4.0         224.90
# 45                 1.0       boleto                   1.0         508.17
# 55                 1.0  credit_card                   1.0          52.24
# 59                 1.0  credit_card                   2.0         151.04
# 60                 1.0  credit_card                   2.0         151.04
#
#                            review_id  review_score      review_comment_title  \
# 3   8d5266042046a06655c8db133d120ba5           4.0          Muito boa a loja
# 19  5a8608437f4b52bec5cd143f37258b5e           5.0                  Nota dez
# 30  9a55cbc65c8fad47581da5ebbb2b373e           5.0                    Ótimo
# 32  2d4303fd561eb4ab51c87faa6598dc10           1.0        NÃO RECOMENDO!!!!
# 33  2d4303fd561eb4ab51c87faa6598dc10           1.0        NÃO RECOMENDO!!!!
# 38  764c587207b9589949abd863bdb72dec           1.0               Enganadores
# 45  b3b4ba30f4ff674b60b53cbb408ad037           5.0   Produto novo e original
# 55  7fe86452ea24bb5085343b5e9d684a3e           5.0                 Excelente
# 59  25b502beeef8b3aff87449ccdc001f53           1.0  Recebi apenas 1 unidade
# 60  25b502beeef8b3aff87449ccdc001f53           1.0  Recebi apenas 1 unidade
#
#                                review_comment_message review_creation_date  \
# 3                                Muito bom o produto.           2018-08-08
# 19  Obrigado pela atenção. Lojas lannister perfeit...           2018-07-03
# 30  Sempre vou comprar aqui pois é a melhor parabéns            2018-08-14
# 32  Até o momento não recebi o produto Protetor De...           2018-06-17
# 33  Até o momento não recebi o produto Protetor De...           2018-06-17
# 38  Foi entregue um produto divergente do que eu h...           2018-05-06
# 45           Produto veio bem lacrado, todo original.           2018-06-19
# 55  Prazo de entrega excelente e produto cuidadosa...           2018-08-03
# 59  Recebi apenas 1 unidade solicitada, deveriam s...           2018-08-01
# 60  Recebi apenas 1 unidade solicitada, deveriam s...           2018-08-01
#
#    review_answer_timestamp
# 3      2018-08-08 18:37:50
# 19     2018-07-03 15:10:07
# 30     2018-08-14 21:52:46
# 32     2018-06-20 11:38:22
# 33     2018-06-20 11:38:22
# 38     2018-05-08 23:47:22
# 45     2018-06-20 00:49:10
# 55     2018-08-04 14:36:31
# 59     2018-08-04 02:14:45
# 60     2018-08-04 02:14:45

# %%
# Ensure datetime columns are properly formatted
date_cols = [
    'order_purchase_timestamp',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]

for col in date_cols:
    sales_data_cleaned[col] = pd.to_datetime(sales_data_cleaned[col])

# Add the new columns
sales_data_cleaned['day'] = sales_data_cleaned['order_purchase_timestamp'].dt.day
sales_data_cleaned['month'] = sales_data_cleaned['order_purchase_timestamp'].dt.month
sales_data_cleaned['purchase_to_delivery'] = sales_data_cleaned['order_delivered_customer_date'] - sales_data_cleaned['order_purchase_timestamp']
sales_data_cleaned['estimated_to_delivery'] = sales_data_cleaned['order_estimated_delivery_date'] - sales_data_cleaned['order_delivered_customer_date']

# Optional: Convert time deltas to numeric days
sales_data_cleaned['purchase_to_delivery_days'] = sales_data_cleaned['purchase_to_delivery'].dt.days
sales_data_cleaned['delivery_delay_days'] = sales_data_cleaned['estimated_to_delivery'].dt.days * -1  # Positive = delay
# Out:
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[col] = pd.to_datetime(sales_data_cleaned[col])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[col] = pd.to_datetime(sales_data_cleaned[col])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned[col] = pd.to_datetime(sales_data_cleaned[col])
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['day'] = sales_data_cleaned['order_purchase_timestamp'].dt.day
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['month'] = sales_data_cleaned['order_purchase_timestamp'].dt.month
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['purchase_to_delivery'] = sales_data_cleaned['order_delivered_customer_date'] - sales_data_cleaned['order_purchase_timestamp']
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['estimated_to_delivery'] = sales_data_cleaned['order_estimated_delivery_date'] - sales_data_cleaned['order_delivered_customer_date']
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['purchase_to_delivery_days'] = sales_data_cleaned['purchase_to_delivery'].dt.days
# C:\Users\hassan\AppData\Local\Temp\ipykernel_17020\3649555221.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data_cleaned['delivery_delay_days'] = sales_data_cleaned['estimated_to_delivery'].dt.days * -1  # Positive = delay

# %%
sales_data_cleaned.head(10)
# Out:
#                             order_id                       customer_id  \
# 3   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 19  dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 30  f3e7c359154d965827355f39d6b1fdac  62b423aab58096ca514ba6aa06be2f98
# 32  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 33  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 38  1790eea0b567cf50911c057cf20f90f9  52142aa69d8d0e1247ab0cada0f76023
# 45  434d158e96bdd6972ad6e6d73ddcfd22  2a1dfb647f32f4390e7b857c67458536
# 55  5820a1100976432c7968a52da59e9364  2b56e94c2f66f2d97cfa63356f69cee8
# 59  9faeb9b2746b9d7526aef5acb08e2aa0  79183cd650e2bb0d475b0067d45946ac
# 60  9faeb9b2746b9d7526aef5acb08e2aa0  79183cd650e2bb0d475b0067d45946ac
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 3     delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 19    delivered      2018-06-07 19:03:12 2018-06-12 23:31:02
# 30    delivered      2018-08-09 11:44:40 2018-08-10 03:24:51
# 32    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
# 33    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
# 38    delivered      2018-04-16 21:15:39 2018-04-16 22:10:26
# 45    delivered      2018-06-01 12:23:13 2018-06-05 03:35:15
# 55    delivered      2018-07-29 11:24:17 2018-07-29 11:44:19
# 59    delivered      2018-07-26 14:39:59 2018-07-26 14:55:10
# 60    delivered      2018-07-26 14:39:59 2018-07-26 14:55:10
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 3           2018-07-26 14:31:00           2018-08-07 15:27:45
# 19          2018-06-11 14:54:00           2018-06-21 15:34:32
# 30          2018-08-10 12:29:00           2018-08-13 18:24:27
# 32          2018-06-05 13:24:00           2018-06-16 15:20:55
# 33          2018-06-05 13:24:00           2018-06-16 15:20:55
# 38          2018-04-18 13:05:09           2018-05-05 12:28:34
# 45          2018-06-08 11:49:00           2018-06-18 21:32:52
# 55          2018-07-30 13:47:00           2018-08-02 22:09:11
# 59          2018-07-27 12:04:00           2018-07-31 22:26:55
# 60          2018-07-27 12:04:00           2018-07-31 22:26:55
#
#    order_estimated_delivery_date  order_item_id  \
# 3                     2018-08-13              1
# 19                    2018-07-04              1
# 30                    2018-08-17              1
# 32                    2018-07-18              1
# 33                    2018-07-18              2
# 38                    2018-05-15              1
# 45                    2018-07-17              1
# 55                    2018-08-13              1
# 59                    2018-08-16              1
# 60                    2018-08-16              2
#
#                           product_id                         seller_id  \
# 3   595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 19  009c09f439988bc06a93d6b8186dce73  89a51f50b8095ea78d5768f34c13a76f
# 30  e99d69efe684efaa643f99805f7c81bc  55c26bcb609f480eb7868594245febb5
# 32  d70f38e7f79c630f8ea00c993897042c  977f9f63dd360c2a32ece2f93ad6d306
# 33  9451e630d725c4bb7a5a206b48b99486  d673a59aac7a70d8b01e6902bf090a11
# 38  2d8f2be4f08788ee3bf5356af2b2ee6c  d91fb3b7d041e83b64a00a3edfb37e4f
# 45  c7df652246ed7b3300aaf46960c141e4  a5cba26a62b8b4d0145b68b841e62e7f
# 55  1deda1acffb44ed38494667d7e49a9f3  f52c2422904463fdd7741f99045fecb6
# 59  f48eb5c2fde13ca63664f0bb05f55346  f7ba60f8c3f99e7ee4042fdef03b70c4
# 60  f48eb5c2fde13ca63664f0bb05f55346  f7ba60f8c3f99e7ee4042fdef03b70c4
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 3  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 19 2018-06-18 18:59:02  132.4          14.05            perfumaria
# 30 2018-08-14 03:24:51   89.9          14.21             papelaria
# 32 2018-06-13 00:35:10   90.9          48.64                 bebes
# 33 2018-06-13 00:35:10   39.5          48.64                 bebes
# 38 2018-04-22 22:10:26  186.9          38.00          climatizacao
# 45 2018-06-13 03:35:15  445.0          63.17          beleza_saude
# 55 2018-07-31 11:44:19   33.9          18.34         esporte_lazer
# 59 2018-07-30 14:55:10   60.0          15.52         esporte_lazer
# 60 2018-07-30 14:55:10   60.0          15.52         esporte_lazer
#
#     product_name_lenght  product_description_lenght  product_photos_qty  \
# 3                  29.0                       178.0                 1.0
# 19                 39.0                       991.0                 3.0
# 30                 56.0                       115.0                 1.0
# 32                 53.0                       233.0                 1.0
# 33                 52.0                       300.0                 1.0
# 38                 52.0                       331.0                 4.0
# 45                 28.0                      1455.0                 1.0
# 55                 53.0                       891.0                 2.0
# 59                 60.0                      1153.0                 2.0
# 60                 60.0                      1153.0                 2.0
#
#     product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 3              400.0               19.0               13.0              19.0
# 19             150.0               20.0               20.0              20.0
# 30             600.0               33.0               13.0              25.0
# 32           10950.0               41.0               40.0              40.0
# 33             350.0               31.0               10.0              12.0
# 38             100.0               27.0               13.0              17.0
# 45             683.0               29.0               15.0              22.0
# 55            1150.0               27.0               12.0              17.0
# 59             100.0               20.0               11.0              11.0
# 60             100.0               20.0               11.0              11.0
#
#    product_category_name_english                customer_unique_id  \
# 3                      perfumery  af07308b275d755c9edb36a90c618231
# 19                     perfumery  ccafc1c3f270410521c3c6f3b249870f
# 30                    stationery  9c9242ad7f1b52d926ea76778e1c0c57
# 32                          baby  576ea0cab426cd8a00fad9a9c90a4494
# 33                          baby  576ea0cab426cd8a00fad9a9c90a4494
# 38              air_conditioning  a6fefcd9f434474cf6fcd8ed1102fd63
# 45                 health_beauty  5f7d7732b351ce851a158528581af05f
# 55                sports_leisure  cc1a30280651daf2d918ed7868575771
# 59                sports_leisure  c77154776ead8e798c2d684205938f71
# 60                sports_leisure  c77154776ead8e798c2d684205938f71
#
#     customer_zip_code_prefix            customer_city customer_state  \
# 3                      47813                barreiras             BA
# 19                     74820                  goiania             GO
# 30                     18052                 sorocaba             SP
# 32                     41213                 salvador             BA
# 33                     41213                 salvador             BA
# 38                     55540                 palmares             PE
# 45                     54330  jaboatao dos guararapes             PE
# 55                     95270          flores da cunha             RS
# 59                     90620             porto alegre             RS
# 60                     90620             porto alegre             RS
#
#     seller_zip_code_prefix            seller_city seller_state  \
# 3                    31570         belo horizonte           SP
# 19                   71931               brasilia           DF
# 30                   14910              tabatinga           SP
# 32                   14910              tabatinga           SP
# 33                   14940               ibitinga           SP
# 38                   11704           praia grande           SP
# 45                   87303           campo mourao           PR
# 55                    9230  santo andre/sao paulo           SP
# 59                    9628  sao bernardo do campo           SP
# 60                    9628  sao bernardo do campo           SP
#
#     payment_sequential payment_type  payment_installments  payment_value  \
# 3                  1.0       boleto                   1.0         141.46
# 19                 1.0  credit_card                  10.0         146.45
# 30                 1.0       boleto                   1.0         104.11
# 32                 1.0  credit_card                  10.0         227.68
# 33                 1.0  credit_card                  10.0         227.68
# 38                 1.0  credit_card                   4.0         224.90
# 45                 1.0       boleto                   1.0         508.17
# 55                 1.0  credit_card                   1.0          52.24
# 59                 1.0  credit_card                   2.0         151.04
# 60                 1.0  credit_card                   2.0         151.04
#
#                            review_id  review_score      review_comment_title  \
# 3   8d5266042046a06655c8db133d120ba5           4.0          Muito boa a loja
# 19  5a8608437f4b52bec5cd143f37258b5e           5.0                  Nota dez
# 30  9a55cbc65c8fad47581da5ebbb2b373e           5.0                    Ótimo
# 32  2d4303fd561eb4ab51c87faa6598dc10           1.0        NÃO RECOMENDO!!!!
# 33  2d4303fd561eb4ab51c87faa6598dc10           1.0        NÃO RECOMENDO!!!!
# 38  764c587207b9589949abd863bdb72dec           1.0               Enganadores
# 45  b3b4ba30f4ff674b60b53cbb408ad037           5.0   Produto novo e original
# 55  7fe86452ea24bb5085343b5e9d684a3e           5.0                 Excelente
# 59  25b502beeef8b3aff87449ccdc001f53           1.0  Recebi apenas 1 unidade
# 60  25b502beeef8b3aff87449ccdc001f53           1.0  Recebi apenas 1 unidade
#
#                                review_comment_message review_creation_date  \
# 3                                Muito bom o produto.           2018-08-08
# 19  Obrigado pela atenção. Lojas lannister perfeit...           2018-07-03
# 30  Sempre vou comprar aqui pois é a melhor parabéns            2018-08-14
# 32  Até o momento não recebi o produto Protetor De...           2018-06-17
# 33  Até o momento não recebi o produto Protetor De...           2018-06-17
# 38  Foi entregue um produto divergente do que eu h...           2018-05-06
# 45           Produto veio bem lacrado, todo original.           2018-06-19
# 55  Prazo de entrega excelente e produto cuidadosa...           2018-08-03
# 59  Recebi apenas 1 unidade solicitada, deveriam s...           2018-08-01
# 60  Recebi apenas 1 unidade solicitada, deveriam s...           2018-08-01
#
#    review_answer_timestamp  day  month purchase_to_delivery  \
# 3      2018-08-08 18:37:50   24      7     13 days 18:46:08
# 19     2018-07-03 15:10:07    7      6     13 days 20:31:20
# 30     2018-08-14 21:52:46    9      8      4 days 06:39:47
# 32     2018-06-20 11:38:22    4      6     12 days 15:20:42
# 33     2018-06-20 11:38:22    4      6     12 days 15:20:42
# 38     2018-05-08 23:47:22   16      4     18 days 15:12:55
# 45     2018-06-20 00:49:10    1      6     17 days 09:09:39
# 55     2018-08-04 14:36:31   29      7      4 days 10:44:54
# 59     2018-08-04 02:14:45   26      7      5 days 07:46:56
# 60     2018-08-04 02:14:45   26      7      5 days 07:46:56
#
#    estimated_to_delivery  purchase_to_delivery_days  delivery_delay_days
# 3        5 days 08:32:15                         13                   -5
# 19      12 days 08:25:28                         13                  -12
# 30       3 days 05:35:33                          4                   -3
# 32      31 days 08:39:05                         12                  -31
# 33      31 days 08:39:05                         12                  -31
# 38       9 days 11:31:26                         18                   -9
# 45      28 days 02:27:08                         17                  -28
# 55      10 days 01:50:49                          4                  -10
# 59      15 days 01:33:05                          5                  -15
# 60      15 days 01:33:05                          5                  -15

# %%
#this is just for test

another_sales_test = sales_data_cleaned.copy()
another_sales_test['is_delayed'] = (
    another_sales_test['order_delivered_customer_date'] > 
    another_sales_test['order_estimated_delivery_date']
).astype(int)

# %%
another_sales_test.sample(10)
# Out:
#                                 order_id                       customer_id  \
# 24088   5601fa41e5818b9941a6bdd21978b6ac  f52d6c5cdf9a2638cf24e11bd300c158
# 99074   11526907a9d9e94078d44fb1c4abb4ec  16c9179622cbd53ac83895bd09ea73c2
# 43782   93670a5c977fd8e687b42178388d9ce7  39dea79a06151bc11ae1cbad542257fa
# 11368   0fcb17f553e4ac7cd19be95d11a1669f  d39dc030d8881866a3061535c0b22c1e
# 23622   ae103e0dfaa3fc6e8b8c9cf179c7a94d  22b43b0d6deb1ba2b9a976af12c6633e
# 102007  827dd37ba0e191a8cce10c6722187e24  6a6f8815c1cf278751f8a0f09c9dcaee
# 57077   e4dfdab4dc28a8727655a0f0a19224b2  a01d949bbd7511dae0779da819c1d8ef
# 38355   aa14b8f4567fef1be1a8912ca010f1c7  cec800e76b1cc898de17926aa9e1e146
# 9990    92f21edc7e69a84e3e521e9adc7c83b8  4e5625bd8071649b275dcce5f9aaec1c
# 182     90349f264a3d6a2525a34598d09dda6b  d19f254a07da73a055409256e9bfe40a
#
#        order_status order_purchase_timestamp   order_approved_at  \
# 24088     delivered      2018-08-20 23:35:44 2018-08-20 23:49:16
# 99074     delivered      2018-08-08 00:56:34 2018-08-09 03:45:28
# 43782     delivered      2018-08-17 14:33:23 2018-08-17 14:50:27
# 11368     delivered      2018-05-10 14:51:36 2018-05-10 15:11:39
# 23622     delivered      2018-06-24 12:51:04 2018-06-24 13:18:36
# 102007    delivered      2018-05-02 15:49:08 2018-05-02 16:19:48
# 57077     delivered      2018-05-24 23:34:05 2018-05-25 23:37:35
# 38355     delivered      2018-08-24 21:17:00 2018-08-24 21:30:16
# 9990      delivered      2018-07-20 21:21:06 2018-07-20 21:30:14
# 182       delivered      2018-05-11 16:35:19 2018-05-12 03:32:26
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 24088           2018-08-22 12:47:00           2018-08-25 18:12:41
# 99074           2018-08-09 20:33:00           2018-08-23 01:35:45
# 43782           2018-08-21 14:24:00           2018-08-28 18:15:50
# 11368           2018-05-10 14:54:00           2018-05-12 00:21:55
# 23622           2018-06-26 14:09:00           2018-06-30 14:28:40
# 102007          2018-05-03 13:48:00           2018-05-07 13:52:34
# 57077           2018-05-30 15:14:00           2018-06-08 19:33:44
# 38355           2018-08-27 12:43:00           2018-08-30 21:32:40
# 9990            2018-07-24 12:33:00           2018-07-27 14:32:57
# 182             2018-05-14 15:16:00           2018-05-15 18:38:39
#
#        order_estimated_delivery_date  order_item_id  \
# 24088                     2018-09-06              5
# 99074                     2018-08-20              1
# 43782                     2018-09-14              1
# 11368                     2018-05-23              1
# 23622                     2018-07-18              1
# 102007                    2018-05-14              1
# 57077                     2018-06-20              1
# 38355                     2018-09-10              1
# 9990                      2018-08-17              3
# 182                       2018-05-21              4
#
#                               product_id                         seller_id  \
# 24088   2265e8aa066cc6c4528d4be900eb5b64  e819bcfade7b5d88a27325eb6cfd62c5
# 99074   03078714f1e3f3758555f67ff35b4b01  594f9aaa48e5bf431f011ddc5669b0d5
# 43782   fc7138a8f96aee8302e42916bbbbb818  28f10b1c5e5abb9d4857745bede6147c
# 11368   cd48f265a63e13b762601f5f794c5fca  e9779976487b77c6d4ac45f75ec7afe9
# 23622   297a5f6e0aaf7b32fb0fc7483944105d  a3e9a2c700480d9bb01fba070ba80a0e
# 102007  c988a235aba9c5a522df4bff0ef2a182  7d456afc660226829370f3173d14520c
# 57077   1a080577618e7fe4d9ddd8fb2b47a964  7d13fca15225358621be4086e1eb0964
# 38355   653db51f38df09a30a8f25e7933050fc  4c8b8048e33af2bf94f2eb547746a916
# 9990    badbf5d003888b6338ea8774b4ac9717  bdae679a9b282249bc23b9b69dae9a99
# 182     216bb0e0cd43ffd832e0973d35e0377e  955fee9216a65b617aa5c0531780ce60
#
#        shipping_limit_date   price  freight_value  \
# 24088  2018-09-05 23:49:16   17.90          15.58
# 99074  2018-08-13 03:45:28   44.90          16.50
# 43782  2018-08-21 14:50:27   17.00          19.04
# 11368  2018-05-17 15:11:39   47.49           9.44
# 23622  2018-06-26 13:18:36  109.00          27.06
# 102007 2018-05-08 16:19:48   22.00           8.29
# 57077  2018-05-30 23:31:50  500.00          15.94
# 38355  2018-08-30 21:30:16  109.90          25.38
# 9990   2018-07-25 21:30:14   65.00          23.57
# 182    2018-05-15 03:30:32   45.00           7.39
#
#                     product_category_name  product_name_lenght  \
# 24088                    moveis_decoracao                 53.0
# 99074               utilidades_domesticas                 54.0
# 43782                         eletronicos                 54.0
# 11368                             bebidas                 48.0
# 23622                     cama_mesa_banho                 44.0
# 102007                         perfumaria                 43.0
# 57077                  relogios_presentes                 33.0
# 38355                         moveis_sala                 51.0
# 9990    construcao_ferramentas_construcao                 46.0
# 182     construcao_ferramentas_iluminacao                 56.0
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 24088                        399.0                 4.0             950.0
# 99074                        153.0                 1.0             600.0
# 43782                       1460.0                 2.0             161.0
# 11368                        859.0                 3.0             175.0
# 23622                        146.0                 1.0            2067.0
# 102007                       446.0                 1.0             450.0
# 57077                        623.0                 1.0             425.0
# 38355                        598.0                 2.0            1350.0
# 9990                         893.0                 1.0            2750.0
# 182                         1082.0                 6.0             200.0
#
#         product_length_cm  product_height_cm  product_width_cm  \
# 24088                40.0               15.0              31.0
# 99074                16.0               16.0              16.0
# 43782                19.0                8.0              17.0
# 11368                23.0               21.0              21.0
# 23622                38.0                5.0              35.0
# 102007               18.0                8.0              18.0
# 57077                19.0               13.0              16.0
# 38355                44.0               14.0              34.0
# 9990                 16.0                2.0              11.0
# 182                  16.0               16.0              16.0
#
#           product_category_name_english                customer_unique_id  \
# 24088                   furniture_decor  2bda8b5ca873c93f2e13ee19397429c8
# 99074                        housewares  b31e6fd7fed8e0d6715a7462820c716a
# 43782                       electronics  0b189e82086064bce001200f6cc9ea29
# 11368                            drinks  58af8ab36593ab5d41e63ba8a55ccc1c
# 23622                    bed_bath_table  6893dccafa43f18f4d29d17a3f770c91
# 102007                        perfumery  3bb7b0684d45bcbaf75a8ec0f49b6223
# 57077                     watches_gifts  ba07856943cc25d23d7950d5beb64553
# 38355             furniture_living_room  001928b561575b2821c92254a2327d06
# 9990    construction_tools_construction  c1e46a3c0e43e74dc1a0704323c2ee3d
# 182           construction_tools_lights  831a032a3327e2b8325faf9d37953870
#
#         customer_zip_code_prefix customer_city customer_state  \
# 24088                       9271   santo andre             SP
# 99074                      24900        marica             RJ
# 43782                      66110         belem             PA
# 11368                       4201     sao paulo             SP
# 23622                      71916      brasilia             DF
# 102007                      1211     sao paulo             SP
# 57077                       8693        suzano             SP
# 38355                       4757     sao paulo             SP
# 9990                       33200    vespasiano             MG
# 182                        13478     americana             SP
#
#         seller_zip_code_prefix      seller_city seller_state  \
# 24088                     7242        guarulhos           SP
# 99074                    32185         contagem           MG
# 43782                     4250        sao paulo           SP
# 11368                    11701     praia grande           SP
# 23622                    14940         ibitinga           SP
# 102007                    8820  mogi das cruzes           SP
# 57077                    14050   ribeirao preto           SP
# 38355                    14940         ibitinga           SP
# 9990                     72210         brasilia           DF
# 182                       4782        sao paulo           SP
#
#         payment_sequential payment_type  payment_installments  payment_value  \
# 24088                  1.0  credit_card                  10.0         226.88
# 99074                  1.0       boleto                   1.0          61.40
# 43782                  1.0  credit_card                   1.0          36.04
# 11368                  1.0  credit_card                   1.0         113.86
# 23622                  1.0  credit_card                   8.0         136.06
# 102007                 1.0  credit_card                   1.0          30.29
# 57077                  1.0  credit_card                   8.0         515.94
# 38355                  1.0  credit_card                   6.0         164.81
# 9990                   1.0  credit_card                   1.0         234.60
# 182                    1.0       boleto                   1.0         314.34
#
#                                review_id  review_score  \
# 24088   2b4137f1cce4b8c184e74488ddcea92f           1.0
# 99074   6737dd321f3984771942c36ea1683b47           5.0
# 43782   0073ab5e971a35e8814d542798699fd6           1.0
# 11368   aa953c2f804822b741052b8b17c2adee           5.0
# 23622   1e427aa9953a542ed820e871814b5525           3.0
# 102007  bb7ad911f1ded2bd11a6f4ad229cfe98           5.0
# 57077   5abe04ed1284e0050b44284b08f3d3c9           2.0
# 38355   58b704fb84caaafe245f49cb9f71a34c           2.0
# 9990    bcc69e9846326d74c92115d0851be33b           1.0
# 182     f8b40a85258a58cf2f04b224cbb8c55c           5.0
#
#             review_comment_title  \
# 24088   Pedido chegou incompleto
# 99074                 Confiável
# 43782      O produto com defeito
# 11368                  MUITO BOA
# 23622                Tecido fino
# 102007                        10
# 57077                   Presente
# 38355           Falta um.produto
# 9990            Produto faltando
# 182                    recomendo
#
#                                    review_comment_message  \
# 24088   Pedido chegou incompleto, abri um chamado e di...
# 99074   A entrega atrasou em apenas um dia. Devido à d...
# 43782   Fiz a instalação como dizia no manual, porém o...
# 11368                                           MUITO BOA
# 23622   A foto não parece com o produto. É um tecido f...
# 102007  Entraga rápida. Gostei de ter comprado pelo si...
# 57077   É presente pro mor só saberei se veio correto ...
# 38355   Não recebi a capa De sofá. Estou aguardando e ...
# 9990    Boa tarde !\r\nComprei tres produtos so chegou...
# 182           Muito bom, apenas uma não está funcionando.
#
#        review_creation_date review_answer_timestamp  day  month  \
# 24088            2018-08-26     2018-08-29 16:45:51   20      8
# 99074            2018-08-23     2018-08-24 13:23:26    8      8
# 43782            2018-08-29     2018-08-31 22:23:11   17      8
# 11368            2018-05-13     2018-05-13 12:10:29   10      5
# 23622            2018-07-01     2018-07-01 18:12:25   24      6
# 102007           2018-05-08     2018-05-10 13:21:24    2      5
# 57077            2018-06-09     2018-06-10 16:08:20   24      5
# 38355            2018-08-31     2018-09-03 09:18:51   24      8
# 9990             2018-07-28     2018-07-28 20:27:37   20      7
# 182              2018-05-16     2018-05-21 13:28:22   11      5
#
#        purchase_to_delivery estimated_to_delivery  purchase_to_delivery_days  \
# 24088       4 days 18:36:57      11 days 05:47:19                          4
# 99074      15 days 00:39:11     -4 days +22:24:15                         15
# 43782      11 days 03:42:27      16 days 05:44:10                         11
# 11368       1 days 09:30:19      10 days 23:38:05                          1
# 23622       6 days 01:37:36      17 days 09:31:20                          6
# 102007      4 days 22:03:26       6 days 10:07:26                          4
# 57077      14 days 19:59:39      11 days 04:26:16                         14
# 38355       6 days 00:15:40      10 days 02:27:20                          6
# 9990        6 days 17:11:51      20 days 09:27:03                          6
# 182         4 days 02:03:20       5 days 05:21:21                          4
#
#         delivery_delay_days  is_delayed
# 24088                   -11           0
# 99074                     4           1
# 43782                   -16           0
# 11368                   -10           0
# 23622                   -17           0
# 102007                   -6           0
# 57077                   -11           0
# 38355                   -10           0
# 9990                    -20           0
# 182                      -5           0

# %%
another_sales_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11578 entries, 3 to 118291
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       11578 non-null  object
#  1   customer_id                    11578 non-null  object
#  2   order_status                   11578 non-null  object
#  3   order_purchase_timestamp       11578 non-null  datetime64[ns]
#  4   order_approved_at              11578 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   11578 non-null  datetime64[ns]
#  6   order_delivered_customer_date  11578 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  11578 non-null  datetime64[ns]
#  8   order_item_id                  11578 non-null  int64
#  9   product_id                     11578 non-null  object
#  10  seller_id                      11578 non-null  object
#  11  shipping_limit_date            11578 non-null  datetime64[ns]
#  12  price                          11578 non-null  float64
#  13  freight_value                  11578 non-null  float64
#  14  product_category_name          11578 non-null  object
#  15  product_name_lenght            11578 non-null  float64
#  16  product_description_lenght     11578 non-null  float64
#  17  product_photos_qty             11578 non-null  float64
#  18  product_weight_g               11578 non-null  float64
#  19  product_length_cm              11578 non-null  float64
#  20  product_height_cm              11578 non-null  float64
#  21  product_width_cm               11578 non-null  float64
#  22  product_category_name_english  11578 non-null  object
#  23  customer_unique_id             11578 non-null  object
#  24  customer_zip_code_prefix       11578 non-null  int64
#  25  customer_city                  11578 non-null  object
#  26  customer_state                 11578 non-null  object
#  27  seller_zip_code_prefix         11578 non-null  int64
#  28  seller_city                    11578 non-null  object
#  29  seller_state                   11578 non-null  object
#  30  payment_sequential             11578 non-null  float64
#  31  payment_type                   11578 non-null  object
#  32  payment_installments           11578 non-null  float64
#  33  payment_value                  11578 non-null  float64
#  34  review_id                      11578 non-null  object
#  35  review_score                   11578 non-null  float64
#  36  review_comment_title           11578 non-null  object
#  37  review_comment_message         11578 non-null  object
#  38  review_creation_date           11578 non-null  datetime64[ns]
#  39  review_answer_timestamp        11578 non-null  datetime64[ns]
#  40  day                            11578 non-null  int32
#  41  month                          11578 non-null  int32
#  42  purchase_to_delivery           11578 non-null  timedelta64[ns]
#  43  estimated_to_delivery          11578 non-null  timedelta64[ns]
#  44  purchase_to_delivery_days      11578 non-null  int64
#  45  delivery_delay_days            11578 non-null  int64
#  46  is_delayed                     11578 non-null  int64
# dtypes: datetime64[ns](8), float64(13), int32(2), int64(6), object(16), timedelta64[ns](2)
# memory usage: 4.2+ MB

# %%
# Add the "delivery_time_days" column
another_sales_test['delivery_time_days'] = (
    another_sales_test['order_delivered_customer_date'] - 
    another_sales_test['order_purchase_timestamp']
).dt.days

# %%
# Add the "is_delayed" flag
another_sales_test['is_delayed2'] = (
    another_sales_test['order_delivered_customer_date'] > 
    another_sales_test['order_estimated_delivery_date']
).astype(int)

# %%
another_sales_test.head()
# Out:
#                             order_id                       customer_id  \
# 3   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 19  dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 30  f3e7c359154d965827355f39d6b1fdac  62b423aab58096ca514ba6aa06be2f98
# 32  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 33  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 3     delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 19    delivered      2018-06-07 19:03:12 2018-06-12 23:31:02
# 30    delivered      2018-08-09 11:44:40 2018-08-10 03:24:51
# 32    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
# 33    delivered      2018-06-04 00:00:13 2018-06-05 00:35:10
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 3           2018-07-26 14:31:00           2018-08-07 15:27:45
# 19          2018-06-11 14:54:00           2018-06-21 15:34:32
# 30          2018-08-10 12:29:00           2018-08-13 18:24:27
# 32          2018-06-05 13:24:00           2018-06-16 15:20:55
# 33          2018-06-05 13:24:00           2018-06-16 15:20:55
#
#    order_estimated_delivery_date  order_item_id  \
# 3                     2018-08-13              1
# 19                    2018-07-04              1
# 30                    2018-08-17              1
# 32                    2018-07-18              1
# 33                    2018-07-18              2
#
#                           product_id                         seller_id  \
# 3   595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 19  009c09f439988bc06a93d6b8186dce73  89a51f50b8095ea78d5768f34c13a76f
# 30  e99d69efe684efaa643f99805f7c81bc  55c26bcb609f480eb7868594245febb5
# 32  d70f38e7f79c630f8ea00c993897042c  977f9f63dd360c2a32ece2f93ad6d306
# 33  9451e630d725c4bb7a5a206b48b99486  d673a59aac7a70d8b01e6902bf090a11
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 3  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 19 2018-06-18 18:59:02  132.4          14.05            perfumaria
# 30 2018-08-14 03:24:51   89.9          14.21             papelaria
# 32 2018-06-13 00:35:10   90.9          48.64                 bebes
# 33 2018-06-13 00:35:10   39.5          48.64                 bebes
#
#     product_name_lenght  product_description_lenght  product_photos_qty  \
# 3                  29.0                       178.0                 1.0
# 19                 39.0                       991.0                 3.0
# 30                 56.0                       115.0                 1.0
# 32                 53.0                       233.0                 1.0
# 33                 52.0                       300.0                 1.0
#
#     product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 3              400.0               19.0               13.0              19.0
# 19             150.0               20.0               20.0              20.0
# 30             600.0               33.0               13.0              25.0
# 32           10950.0               41.0               40.0              40.0
# 33             350.0               31.0               10.0              12.0
#
#    product_category_name_english                customer_unique_id  \
# 3                      perfumery  af07308b275d755c9edb36a90c618231
# 19                     perfumery  ccafc1c3f270410521c3c6f3b249870f
# 30                    stationery  9c9242ad7f1b52d926ea76778e1c0c57
# 32                          baby  576ea0cab426cd8a00fad9a9c90a4494
# 33                          baby  576ea0cab426cd8a00fad9a9c90a4494
#
#     customer_zip_code_prefix customer_city customer_state  \
# 3                      47813     barreiras             BA
# 19                     74820       goiania             GO
# 30                     18052      sorocaba             SP
# 32                     41213      salvador             BA
# 33                     41213      salvador             BA
#
#     seller_zip_code_prefix     seller_city seller_state  payment_sequential  \
# 3                    31570  belo horizonte           SP                 1.0
# 19                   71931        brasilia           DF                 1.0
# 30                   14910       tabatinga           SP                 1.0
# 32                   14910       tabatinga           SP                 1.0
# 33                   14940        ibitinga           SP                 1.0
#
#    payment_type  payment_installments  payment_value  \
# 3        boleto                   1.0         141.46
# 19  credit_card                  10.0         146.45
# 30       boleto                   1.0         104.11
# 32  credit_card                  10.0         227.68
# 33  credit_card                  10.0         227.68
#
#                            review_id  review_score review_comment_title  \
# 3   8d5266042046a06655c8db133d120ba5           4.0     Muito boa a loja
# 19  5a8608437f4b52bec5cd143f37258b5e           5.0             Nota dez
# 30  9a55cbc65c8fad47581da5ebbb2b373e           5.0               Ótimo
# 32  2d4303fd561eb4ab51c87faa6598dc10           1.0   NÃO RECOMENDO!!!!
# 33  2d4303fd561eb4ab51c87faa6598dc10           1.0   NÃO RECOMENDO!!!!
#
#                                review_comment_message review_creation_date  \
# 3                                Muito bom o produto.           2018-08-08
# 19  Obrigado pela atenção. Lojas lannister perfeit...           2018-07-03
# 30  Sempre vou comprar aqui pois é a melhor parabéns            2018-08-14
# 32  Até o momento não recebi o produto Protetor De...           2018-06-17
# 33  Até o momento não recebi o produto Protetor De...           2018-06-17
#
#    review_answer_timestamp  day  month purchase_to_delivery  \
# 3      2018-08-08 18:37:50   24      7     13 days 18:46:08
# 19     2018-07-03 15:10:07    7      6     13 days 20:31:20
# 30     2018-08-14 21:52:46    9      8      4 days 06:39:47
# 32     2018-06-20 11:38:22    4      6     12 days 15:20:42
# 33     2018-06-20 11:38:22    4      6     12 days 15:20:42
#
#    estimated_to_delivery  purchase_to_delivery_days  delivery_delay_days  \
# 3        5 days 08:32:15                         13                   -5
# 19      12 days 08:25:28                         13                  -12
# 30       3 days 05:35:33                          4                   -3
# 32      31 days 08:39:05                         12                  -31
# 33      31 days 08:39:05                         12                  -31
#
#     is_delayed  delivery_time_days  is_delayed2
# 3            0                  13            0
# 19           0                  13            0
# 30           0                   4            0
# 32           0                  12            0
# 33           0                  12            0

# %%
another_sales_test['is_delayed'].value_counts()
# Out:
# is_delayed
# 0    10667
# 1      911
# Name: count, dtype: int64

# %%
another_sales_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11578 entries, 3 to 118291
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       11578 non-null  object
#  1   customer_id                    11578 non-null  object
#  2   order_status                   11578 non-null  object
#  3   order_purchase_timestamp       11578 non-null  datetime64[ns]
#  4   order_approved_at              11578 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   11578 non-null  datetime64[ns]
#  6   order_delivered_customer_date  11578 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  11578 non-null  datetime64[ns]
#  8   order_item_id                  11578 non-null  int64
#  9   product_id                     11578 non-null  object
#  10  seller_id                      11578 non-null  object
#  11  shipping_limit_date            11578 non-null  datetime64[ns]
#  12  price                          11578 non-null  float64
#  13  freight_value                  11578 non-null  float64
#  14  product_category_name          11578 non-null  object
#  15  product_name_lenght            11578 non-null  float64
#  16  product_description_lenght     11578 non-null  float64
#  17  product_photos_qty             11578 non-null  float64
#  18  product_weight_g               11578 non-null  float64
#  19  product_length_cm              11578 non-null  float64
#  20  product_height_cm              11578 non-null  float64
#  21  product_width_cm               11578 non-null  float64
#  22  product_category_name_english  11578 non-null  object
#  23  customer_unique_id             11578 non-null  object
#  24  customer_zip_code_prefix       11578 non-null  int64
#  25  customer_city                  11578 non-null  object
#  26  customer_state                 11578 non-null  object
#  27  seller_zip_code_prefix         11578 non-null  int64
#  28  seller_city                    11578 non-null  object
#  29  seller_state                   11578 non-null  object
#  30  payment_sequential             11578 non-null  float64
#  31  payment_type                   11578 non-null  object
#  32  payment_installments           11578 non-null  float64
#  33  payment_value                  11578 non-null  float64
#  34  review_id                      11578 non-null  object
#  35  review_score                   11578 non-null  float64
#  36  review_comment_title           11578 non-null  object
#  37  review_comment_message         11578 non-null  object
#  38  review_creation_date           11578 non-null  datetime64[ns]
#  39  review_answer_timestamp        11578 non-null  datetime64[ns]
#  40  day                            11578 non-null  int32
#  41  month                          11578 non-null  int32
#  42  purchase_to_delivery           11578 non-null  timedelta64[ns]
#  43  estimated_to_delivery          11578 non-null  timedelta64[ns]
#  44  purchase_to_delivery_days      11578 non-null  int64
#  45  delivery_delay_days            11578 non-null  int64
#  46  is_delayed                     11578 non-null  int64
#  47  delivery_time_days             11578 non-null  int64
#  48  is_delayed2                    11578 non-null  int64
# dtypes: datetime64[ns](8), float64(13), int32(2), int64(8), object(16), timedelta64[ns](2)
# memory usage: 4.3+ MB
