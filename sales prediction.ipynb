# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_customers_dataset.csv')
order_items_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_items_dataset.csv')
order_payments_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_payments_dataset.csv')
order_reviews_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_reviews_dataset.csv')
orders_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_orders_dataset.csv')
products_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_products_dataset.csv')
sellers_dataset = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_sellers_dataset.csv')
product_category_name_translation = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/product_category_name_translation.csv')

# %%
customers_dataset.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
order_items_dataset.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_dataset.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_dataset.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_dataset.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products_dataset.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
import pandas as pd

# Load datasets
customers_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_customers_dataset.csv')
order_items_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_items_dataset.csv')
order_payments_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_payments_dataset.csv')
order_reviews_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_order_reviews_dataset.csv')
orders_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_orders_dataset.csv')
products_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_products_dataset.csv')
sellers_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/olist_sellers_dataset.csv')
product_cat_trans_df = pd.read_csv('/Users/ahmedsherif/Downloads/archive (1)/product_category_name_translation.csv')

# 1. Merge orders with customers using 'customer_id'
df = pd.merge(orders_df, customers_df, on='customer_id', how='left')

# 2. Merge with order items using 'order_id'
df = pd.merge(df, order_items_df, on='order_id', how='left')

# 3. Merge with order payments using 'order_id'
df = pd.merge(df, order_payments_df, on='order_id', how='left')

# 4. Merge with order reviews using 'order_id'
df = pd.merge(df, order_reviews_df, on='order_id', how='left')

# 5. Merge with sellers data using 'seller_id' (from order_items)
df = pd.merge(df, sellers_df, on='seller_id', how='left')

# 6. Merge with products data using 'product_id'
df = pd.merge(df, products_df, on='product_id', how='left')

# 7. Merge with product category translation to get readable category names
df = pd.merge(df, product_cat_trans_df, on='product_category_name', how='left')



# Now, df is your fully merged DataFrame
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  object
#  4   order_approved_at              118966 non-null  object
#  5   order_delivered_carrier_date   117057 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  119143 non-null  object
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  object
#  11  customer_state                 119143 non-null  object
# ...

# %%
df.drop(columns=['review_comment_message', 'review_comment_title','product_name_lenght','product_description_lenght','product_photos_qty'],inplace = True)

# %%
df_clean = df.dropna()

# %%
for column in df.columns:
    null_count = df[column].isnull().sum()
    total_count = len(df)
    null_percentage = (null_count / total_count) * 100
    print(f"Column: {column}, Null Percentage: {null_percentage:.2f}%")
# Out:
# Column: order_id, Null Percentage: 0.00%
# Column: customer_id, Null Percentage: 0.00%
# Column: order_status, Null Percentage: 0.00%
# Column: order_purchase_timestamp, Null Percentage: 0.00%
# Column: order_approved_at, Null Percentage: 0.15%
# Column: order_delivered_carrier_date, Null Percentage: 1.75%
# Column: order_delivered_customer_date, Null Percentage: 2.87%
# Column: order_estimated_delivery_date, Null Percentage: 0.00%
# Column: customer_unique_id, Null Percentage: 0.00%
# Column: customer_zip_code_prefix, Null Percentage: 0.00%
# Column: customer_city, Null Percentage: 0.00%
# Column: customer_state, Null Percentage: 0.00%
# Column: order_item_id, Null Percentage: 0.70%
# Column: product_id, Null Percentage: 0.70%
# Column: seller_id, Null Percentage: 0.70%
# Column: shipping_limit_date, Null Percentage: 0.70%
# Column: price, Null Percentage: 0.70%
# Column: freight_value, Null Percentage: 0.70%
# Column: payment_sequential, Null Percentage: 0.00%
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113193 entries, 0 to 119142
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113193 non-null  object
#  1   customer_id                    113193 non-null  object
#  2   order_status                   113193 non-null  object
#  3   order_purchase_timestamp       113193 non-null  object
#  4   order_approved_at              113193 non-null  object
#  5   order_delivered_carrier_date   113193 non-null  object
#  6   order_delivered_customer_date  113193 non-null  object
#  7   order_estimated_delivery_date  113193 non-null  object
#  8   customer_unique_id             113193 non-null  object
#  9   customer_zip_code_prefix       113193 non-null  int64
#  10  customer_city                  113193 non-null  object
#  11  customer_state                 113193 non-null  object
# ...

# %%
for column in df_clean.columns:
    null_count = df_clean[column].isnull().sum()
    total_count = len(df_clean)
    null_percentage = (null_count / total_count) * 100
    print(f"Column: {column}, Null Percentage: {null_percentage:.2f}%")
# Out:
# Column: order_id, Null Percentage: 0.00%
# Column: customer_id, Null Percentage: 0.00%
# Column: order_status, Null Percentage: 0.00%
# Column: order_purchase_timestamp, Null Percentage: 0.00%
# Column: order_approved_at, Null Percentage: 0.00%
# Column: order_delivered_carrier_date, Null Percentage: 0.00%
# Column: order_delivered_customer_date, Null Percentage: 0.00%
# Column: order_estimated_delivery_date, Null Percentage: 0.00%
# Column: customer_unique_id, Null Percentage: 0.00%
# Column: customer_zip_code_prefix, Null Percentage: 0.00%
# Column: customer_city, Null Percentage: 0.00%
# Column: customer_state, Null Percentage: 0.00%
# Column: order_item_id, Null Percentage: 0.00%
# Column: product_id, Null Percentage: 0.00%
# Column: seller_id, Null Percentage: 0.00%
# Column: shipping_limit_date, Null Percentage: 0.00%
# Column: price, Null Percentage: 0.00%
# Column: freight_value, Null Percentage: 0.00%
# Column: payment_sequential, Null Percentage: 0.00%
# ...

# %%
df_clean.count()
# Out:
# order_id                         113193
# customer_id                      113193
# order_status                     113193
# order_purchase_timestamp         113193
# order_approved_at                113193
# order_delivered_carrier_date     113193
# order_delivered_customer_date    113193
# order_estimated_delivery_date    113193
# customer_unique_id               113193
# customer_zip_code_prefix         113193
# customer_city                    113193
# customer_state                   113193
# order_item_id                    113193
# product_id                       113193
# seller_id                        113193
# shipping_limit_date              113193
# price                            113193
# freight_value                    113193
# payment_sequential               113193
# payment_type                     113193
# payment_installments             113193
# payment_value                    113193
# review_id                        113193
# ...

# %%
date_cols = [
    'shipping_limit_date', 
    'order_purchase_timestamp', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
    'order_estimated_delivery_date', 
    'review_creation_date', 
    'review_answer_timestamp'
]

df_clean[date_cols] = df_clean[date_cols].apply(pd.to_datetime)
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/1119154036.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[date_cols] = df_clean[date_cols].apply(pd.to_datetime)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113193 entries, 0 to 119142
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113193 non-null  object
#  1   customer_id                    113193 non-null  object
#  2   order_status                   113193 non-null  object
#  3   order_purchase_timestamp       113193 non-null  datetime64[ns]
#  4   order_approved_at              113193 non-null  object
#  5   order_delivered_carrier_date   113193 non-null  datetime64[ns]
#  6   order_delivered_customer_date  113193 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  113193 non-null  datetime64[ns]
#  8   customer_unique_id             113193 non-null  object
#  9   customer_zip_code_prefix       113193 non-null  int64
#  10  customer_city                  113193 non-null  object
# ...

# %%
df_clean.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value', 'review_id',
#        'review_score', 'review_creation_date', 'review_answer_timestamp',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state',
#        'product_category_name', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm',
#        'product_category_name_english'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', 1000)

# %%
df_clean.head()
# Out:
#                            order_id                       customer_id order_status order_purchase_timestamp    order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date                customer_unique_id  customer_zip_code_prefix customer_city customer_state  order_item_id                        product_id                         seller_id shipping_limit_date   price  freight_value  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score review_creation_date review_answer_timestamp  seller_zip_code_prefix     seller_city seller_state  product_category_name  product_weight_g  product_length_cm  product_height_cm  product_width_cm product_category_name_english  delay_days  delay_time  total_spend
# ...

# %%
df_clean.describe()
# Out:
#             order_purchase_timestamp   order_delivered_carrier_date  order_delivered_customer_date  order_estimated_delivery_date  customer_zip_code_prefix  order_item_id            shipping_limit_date          price  freight_value  payment_sequential  payment_installments  payment_value   review_score           review_creation_date        review_answer_timestamp  seller_zip_code_prefix  product_weight_g  product_length_cm  product_height_cm  product_width_cm
# count                         113193                         113193                         113193                         113193             113193.000000  113193.000000                         113193  113193.000000  113193.000000       113193.000000         113193.000000  113193.000000  113193.000000                         113193                         113193           113193.000000     113193.000000      113193.000000      113193.000000     113193.000000
# ...

# %%
count_of_items_per_order = df['order_item_id'].value_counts()
count_of_items_per_order
# Out:
# order_item_id
# 1.0     103645
# 2.0      10317
# 3.0       2396
# 4.0        995
# 5.0        472
# 6.0        265
# 7.0         61
# 8.0         37
# 9.0         29
# 10.0        26
# 11.0        18
# 12.0        13
# 13.0         8
# 14.0         7
# 15.0         5
# 16.0         3
# 17.0         3
# 18.0         3
# 19.0         3
# 20.0         3
# 21.0         1
# Name: count, dtype: int64

# %%
df_clean.groupby('order_id')['order_item_id'].count().nunique()
# Out:
# 24

# %%
#most of the order are single orders
count_of_items_per_order = df['order_item_id'].value_counts()
per = count_of_items_per_order/count_of_items_per_order.sum()*100
per
# Out:
# order_item_id
# 1.0     87.604598
# 2.0      8.720311
# 3.0      2.025188
# 4.0      0.841011
# 5.0      0.398952
# 6.0      0.223988
# 7.0      0.051559
# 8.0      0.031274
# 9.0      0.024512
# 10.0     0.021976
# 11.0     0.015214
# 12.0     0.010988
# 13.0     0.006762
# 14.0     0.005917
# 15.0     0.004226
# 16.0     0.002536
# 17.0     0.002536
# 18.0     0.002536
# 19.0     0.002536
# 20.0     0.002536
# 21.0     0.000845
# Name: count, dtype: float64

# %%
count_of_items_per_order.plot(kind = 'bar')
plt.xlabel('count of items per order')
plt.ylabel('count of orders')
# Out:
# Text(0, 0.5, 'count of orders')

# %%
# highest number of items in a single order
df['order_item_id'].max()
# Out:
# 21.0

# %%
order_stat = df_clean['order_status'].value_counts()
order_stat
# Out:
# order_status
# delivered    113186
# canceled          7
# Name: count, dtype: int64

# %%
sns.countplot(x = df_clean['order_status'] , data =df_clean)
# Out:
# <Axes: xlabel='order_status', ylabel='count'>

# %%
df_clean['delay_days'] = (
    df_clean['order_delivered_customer_date'] - df_clean['order_estimated_delivery_date']).dt.days
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/3313035439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['delay_days'] = (

# %%
df_clean['delay_time'] = (
    df_clean['order_delivered_customer_date'] - df_clean['order_estimated_delivery_date']).dt.days
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/4241117364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['delay_time'] = (

# %%
num_delayed_orders = df_clean[df_clean['delay_time'] > 0].shape[0]
num_delayed_orders
# Out:
# 7246

# %%
num_non_delayed_orders =df_clean[df_clean['delay_time'] < 0].shape[0]
num_non_delayed_orders
# Out:
# 104479

# %%
x = pd.DataFrame({'delayed_orders' : [num_delayed_orders] , 'not_delayed_orders' : [num_non_delayed_orders]})
x
# Out:
#    delayed_orders  not_delayed_orders
# 0            7246              104479

# %%
x.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.scatterplot(x='review_score' , y = 'delay_days' , data = df_clean)
# Out:
# <Axes: xlabel='review_score', ylabel='delay_days'>

# %%
filter_df1 = df_clean[df_clean['delay_days'] >= 0 ]
filter_df1
# Out:
#                                 order_id                       customer_id order_status order_purchase_timestamp    order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date                customer_unique_id  customer_zip_code_prefix         customer_city customer_state  order_item_id                        product_id                         seller_id shipping_limit_date   price  freight_value  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score review_creation_date review_answer_timestamp  seller_zip_code_prefix          seller_city seller_state  product_category_name  product_weight_g  product_length_cm  product_height_cm  product_width_cm product_category_name_english  delay_days  delay_time
# ...

# %%
sns.scatterplot(x = 'review_score',y = 'delay_days' , data = filter_df1)
# Out:
# <Axes: xlabel='review_score', ylabel='delay_days'>

# %%
filter_df2 = df_clean[df_clean['delay_days'] <= 0 ]

# %%
sns.scatterplot(x = 'review_score',y = 'delay_days' , data = filter_df2)
# Out:
# <Axes: xlabel='review_score', ylabel='delay_days'>

# %%
df_clean['delay_time'] = df_clean['delay_time'].astype(int)
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/1556025982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['delay_time'] = df_clean['delay_time'].astype(int)

# %%
df_clean['delay_days'] = df_clean['delay_days'].apply(lambda x: max(0,x))
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/4074525748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['delay_days'] = df_clean['delay_days'].apply(lambda x: max(0,x))

# %%
sns.scatterplot(x='order_status', y='delay_days', data=df_clean)
plt.xticks(rotation=45)
plt.title("Relation between Order Status and Delay Days")
# Out:
# Text(0.5, 1.0, 'Relation between Order Status and Delay Days')

# %%
sns.scatterplot(x='order_status', y='delay_time', data=df_clean)
plt.xticks(rotation=45)
plt.title("Relation between Order Status and Delay Days")
# Out:
# Text(0.5, 1.0, 'Relation between Order Status and Delay Days')

# %%
order_price = df.groupby('order_id')['price'].sum().nlargest(5)
order_price
# Out:
# order_id
# 03caa2c082116e1d31e67e9ae3700499    13440.00
# fa65dad1b0e818e3ccc5cb0e39231352    11383.95
# 4bfcba9e084f46c8e3cb49b0fa6e6159    10856.10
# 465c2e1bee4561cb39e0db8c5993aafc     9888.00
# f489949dbe23cf9313deb342913ece0c     9520.14
# Name: price, dtype: float64

# %%
#top 5 orders by price
order_price.plot(kind = 'bar')
# Out:
# <Axes: xlabel='order_id'>

# %%
# categories with the heighst price baid for
heighst_price_categories = df_clean.groupby('product_category_name_english')['price'].sum().nlargest(10)
heighst_price_categories
# Out:
# product_category_name_english
# health_beauty            1267072.48
# watches_gifts            1207355.40
# bed_bath_table           1081890.33
# sports_leisure            989555.18
# computers_accessories     922482.79
# furniture_decor           746376.54
# housewares                646232.97
# cool_stuff                628288.57
# auto                      594877.24
# garden_tools              490316.78
# Name: price, dtype: float64

# %%
heighst_price_categories.plot(kind = 'bar')
# Out:
# <Axes: xlabel='product_category_name_english'>

# %%
most_delayed_categories = df_clean.groupby('product_category_name_english')['delay_days'].sum().nlargest(10)
most_delayed_categories
# Out:
# product_category_name_english
# bed_bath_table           8482
# health_beauty            7047
# furniture_decor          5911
# sports_leisure           5659
# computers_accessories    5058
# watches_gifts            4187
# housewares               4097
# auto                     3420
# garden_tools             3083
# telephony                2915
# Name: delay_days, dtype: int64

# %%
most_delayed_categories.plot(kind = 'bar')
plt.ylabel('delay_days')
# Out:
# Text(0, 0.5, 'delay_days')

# %%
df_clean.groupby('price')['order_item_id'].sum().sort_values()
# Out:
# price
# 126.97       1.0
# 146.49       1.0
# 146.50       1.0
# 146.65       1.0
# 146.73       1.0
#            ...
# 29.90     1683.0
# 89.90     1776.0
# 69.90     2361.0
# 49.90     2469.0
# 59.90     3188.0
# Name: order_item_id, Length: 5773, dtype: float64

# %%
df_clean['total_spend'] = df_clean.groupby('order_id')['price'].transform('sum')
df_clean['total_spend']
# Out:
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3130/1485694663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['total_spend'] = df_clean.groupby('order_id')['price'].transform('sum')
# 0          89.97
# 1          89.97
# 2          89.97
# 3         118.70
# 4         159.90
#            ...
# 119138    174.90
# 119139    205.99
# 119140    359.98
# 119141    359.98
# 119142     68.50
# Name: total_spend, Length: 113193, dtype: float64

# %%
sns.scatterplot(x=df_clean.groupby('order_id')['order_item_id'].count(), y=df_clean.groupby('order_id')['total_spend'].sum())
plt.xlabel('Number of Items in Order')
plt.ylabel('Total Spend')
plt.title('Relationship Between Number of Items and Total Spend')
plt.show()

# %%
sns.scatterplot(x=df_clean.groupby('order_id')['order_item_id'].count(), y = df_clean.groupby('order_id')['delay_days'].median() , data = df_clean)
plt.xlabel('Number of Items in Order')
plt.ylabel('delay days')
plt.title('Relationship Between Number of Items and delay_days')
plt.show()

# %%
df_clean.groupby('order_id')['order_item_id'].nunique().max()
# Out:
# 21

# %% [markdown]
# Data Summarization:
#
# 1 - How many items are typically in each order , and heighst amount of items in order
#
# 2 - most orders are a single-item type of orders
#
# 3 - how many orderd deliverd and how many orderd got canceled
#
# 4 - top 5 orders by price
#
# 5 - categories with the heighst price baid for
#
# 6 - relation between delayed orders and review score
#
# 7 - relation between delayed orders and order status
#
# 8 - heighst delay days per category
#
# 9 - Relationship Between Number of Items and Total Spend
#
# 10 -Relationship Between Number of Items and delay_days
